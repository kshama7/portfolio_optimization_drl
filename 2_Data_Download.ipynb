# %% [markdown]
# # Portfolio Optimization using Deep Reinforcement Learning
# ----

# %% [markdown]
# ## 2.0 Download the Data for the Analysis
# ---
# * Data is Downloaded from niftyfiftyindices.com
# * The NIFTY 50 tickers for the period from 20018 to 2024 are used
# * The data is downloaded and the cleaned data are saved in csv files for use
#
# ---

# %% [markdown]
# ### 2.1 Import Relevant Packages

# %%
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /private/var/folders/3z/6b2hp23s5sg2j9x4jt4hyh_80000gn/T/pip-req-build-r72v8iu9
#   Running command git clone --quiet https://github.com/AI4Finance-Foundation/FinRL.git /private/var/folders/3z/6b2hp23s5sg2j9x4jt4hyh_80000gn/T/pip-req-build-r72v8iu9
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit ccf56f5e7f6760da87998622148a502b92be962a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl (from finrl==0.3.6)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /private/var/folders/3z/6b2hp23s5sg2j9x4jt4hyh_80000gn/T/pip-install-qfwqpak_/elegantrl_73d816759aa64e76bd11dd663b717866
#   Running command git clone --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /private/var/folders/3z/6b2hp23s5sg2j9x4jt4hyh_80000gn/T/pip-install-qfwqpak_/elegantrl_73d816759aa64e76bd11dd663b717866
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit b64df20f552477f24ec50c3e5088c1e241fdc455
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl==0.3.6) (3.2.0)
# Requirement already satisfied: ccxt<4,>=3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl==0.3.6) (3.1.60)
# Requirement already satisfied: exchange-calendars<5,>=4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl==0.3.6) (4.5.3)
# Requirement already satisfied: jqdatasdk<2,>=1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl==0.3.6) (1.9.3)
# Requirement already satisfied: pyfolio<0.10,>=0.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl==0.3.6) (0.9.2+75.g4b901f6)
# Requirement already satisfied: pyportfolioopt<2,>=1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl==0.3.6) (1.5.5)
# Requirement already satisfied: ray<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.10.0)
# Requirement already satisfied: scikit-learn<2,>=1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl==0.3.6) (1.4.1.post1)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.3.0a4)
# Requirement already satisfied: stockstats<0.6,>=0.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl==0.3.6) (0.5.4)
# Requirement already satisfied: wrds<4,>=3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl==0.3.6) (3.2.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl==0.3.6) (0.2.37)
# Requirement already satisfied: pandas>=0.18.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.2.1)
# Requirement already satisfied: numpy>=1.11.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.4)
# Requirement already satisfied: requests<3,>2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.31.0)
# Requirement already satisfied: urllib3<2,>1.24 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.18)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.7.0)
# Requirement already satisfied: websockets<11,>=9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (10.4)
# Requirement already satisfied: msgpack==1.0.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.0.3)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (3.9.3)
# Requirement already satisfied: PyYAML==6.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.2)
# Requirement already satisfied: setuptools>=60.9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (69.2.0)
# Requirement already satisfied: certifi>=2018.1.18 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (2024.2.2)
# Requirement already satisfied: cryptography>=2.6.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (42.0.5)
# Requirement already satisfied: aiodns>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (3.1.1)
# Requirement already satisfied: yarl>=1.7.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (1.9.4)
# Requirement already satisfied: pyluach in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: toolz in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.12.1)
# Requirement already satisfied: tzdata in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2024.1)
# Requirement already satisfied: korean-lunar-calendar in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.3.1)
# Requirement already satisfied: six in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (2.0.29)
# Requirement already satisfied: thriftpy2>=0.3.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (0.4.20)
# Requirement already satisfied: pymysql>=0.7.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.1.0)
# Requirement already satisfied: ipython>=3.2.3 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (8.22.2)
# Requirement already satisfied: matplotlib>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (3.8.3)
# Requirement already satisfied: pytz>=2014.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (2024.1)
# Requirement already satisfied: scipy>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (1.12.0)
# Requirement already satisfied: seaborn>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.13.2)
# Requirement already satisfied: empyrical>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.5.5)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.6) (1.4.2)
# Requirement already satisfied: click>=7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (8.1.7)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (3.13.3)
# Requirement already satisfied: jsonschema in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (4.21.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (4.25.3)
# Requirement already satisfied: aiosignal in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: frozenlist in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (1.4.1)
# Requirement already satisfied: aiohttp-cors in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: colorful in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.14)
# Requirement already satisfied: opencensus in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.11.4)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.6.4)
# Requirement already satisfied: prometheus-client>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.20.0)
# Requirement already satisfied: smart-open in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (7.0.4)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (20.25.1)
# Requirement already satisfied: grpcio>=1.42.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.62.1)
# Requirement already satisfied: tensorboardX>=1.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (15.0.2)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2024.3.1)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (3.4.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.29.1)
# Requirement already satisfied: torch>=1.13 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.2.2)
# Requirement already satisfied: cloudpickle in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.9.0.80)
# Requirement already satisfied: pygame in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.16.2)
# Requirement already satisfied: psutil in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.9.8)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.66.2)
# Requirement already satisfied: rich in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (13.7.1)
# Requirement already satisfied: shimmy~=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: pillow in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (10.2.0)
# Requirement already satisfied: autorom~=0.6.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from wrds<4,>=3->finrl==0.3.6) (2.9.9)
# Requirement already satisfied: multitasking>=0.0.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (5.1.0)
# Requirement already satisfied: appdirs>=1.4.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.1)
# Requirement already satisfied: gym in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.26.2)
# Requirement already satisfied: pycares>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.6) (4.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.6) (4.0.3)
# Requirement already satisfied: AutoROM.accept-rom-license in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.6.1)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.6) (2.5)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: osqp>=0.6.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.6.4)
# Requirement already satisfied: ecos>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (2.0.13)
# Requirement already satisfied: clarabel>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.7.1)
# Requirement already satisfied: scs>=3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (3.2.4.post1)
# Requirement already satisfied: pybind11 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (2.12.0)
# Requirement already satisfied: pandas-datareader>=0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.0.4)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from html5lib>=1.1->yfinance<0.3,>=0.2->finrl==0.3.6) (0.5.1)
# Requirement already satisfied: decorator in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.17.2)
# Requirement already satisfied: stack-data in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.14.2)
# Requirement already satisfied: exceptiongroup in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<3,>=2->finrl==0.3.6) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<3,>=2->finrl==0.3.6) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.6)
# Requirement already satisfied: ale-py~=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.1)
# Requirement already satisfied: ply<4.0,>=3.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from thriftpy2>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6) (3.11)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.12)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.2.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.3)
# Requirement already satisfied: distlib<1,>=0.3.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.8)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (4.2.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.0.8)
# Requirement already satisfied: box2d-py==2.3.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym[box2d]->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (2.3.5)
# Requirement already satisfied: swig==4.* in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym[box2d]->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (4.2.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.6) (0.18.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from smart-open->ray[default,tune]<3,>=2->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: importlib-resources in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (6.4.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.63.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.23.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.29.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.1.2)
# Requirement already satisfied: qdldl in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from osqp>=0.6.2->cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.6) (0.1.7.post0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.5)
# Requirement already satisfied: executing>=1.2.0 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sympy->torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.6.0)

# %%
import pandas as pd
import numpy as np
from config import config
import matplotlib.pylab as plt

import yfinance as yf
from pandas_datareader import data as pdr

# %matplotlib inline

# %% [markdown]
# ### 2.2 Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# ### 2.3 Download the NIFTY 50 Stocks

# %%
pip install niftystocks
# Out:
# Requirement already satisfied: niftystocks in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from niftystocks import ns

# %%
import pandas as pd

url = "/Users/kshama/Documents/Capstone Options/Capstone-Indian data/MW-NIFTY-50-18-Apr-2024.csv"

# Download and read the CSV file
data = pd.read_csv(url)

# %%
data.head()
# Out:
#     SYMBOL \n    OPEN \n    HIGH \n     LOW \n PREV. CLOSE \n     LTP \n  \
# 0    NIFTY 50  22,212.35  22,295.55  22,153.80      22,147.90  22,275.80
# 1   POWERGRID     287.90     289.90     277.70         274.25     284.30
# 2        BPCL     604.50     617.60     601.05         592.30     609.85
# 3  BHARTIARTL   1,220.00   1,251.00   1,215.80       1,216.45   1,248.70
# 4    HINDALCO     616.40     623.25     612.45         608.85     623.00
#
#    CHNG \n  %CHNG \n VOLUME \n(shares) VALUE \n (₹ Crores)   52W H \n  \
# 0   127.90      0.58      16,76,82,489           14,901.27  22,775.70
# 1    10.05      3.66       2,53,88,211              719.37     298.90
# 2    17.55      2.96         63,77,691              389.83     687.95
# 3    32.25      2.65         53,88,787              662.63   1,251.00
# 4    14.15      2.32         31,29,079              193.34     625.40
#
#     52W L \n  30 D   %CHNG \n  365 D % CHNG \n 18-Apr-2023
# 0  17,553.95             0.42                        25.41
# 1     171.49             3.53                        19.08
# 2     330.30             1.72                        76.91
# 3     752.55            -0.72                        60.11
# 4     397.80            14.63                        41.08

# %%
nifty_50_tickers = data["SYMBOL \n"].tolist()

# %%
print(nifty_50_tickers)
# Out:
# ['NIFTY 50', 'POWERGRID', 'BPCL', 'BHARTIARTL', 'HINDALCO', 'GRASIM', 'M&M', 'ADANIPORTS', 'HDFCLIFE', 'LT', 'TATASTEEL', 'TCS', 'LTIM', 'EICHERMOT', 'TATACONSUM', 'SHRIRAMFIN', 'SBILIFE', 'BAJAJ-AUTO', 'JSWSTEEL', 'DRREDDY', 'KOTAKBANK', 'INFY', 'ASIANPAINT', 'ADANIENT', 'INDUSINDBK', 'WIPRO', 'RELIANCE', 'COALINDIA', 'CIPLA', 'BAJAJFINSV', 'SBIN', 'HINDUNILVR', 'ULTRACEMCO', 'NTPC', 'TATAMOTORS', 'TECHM', 'HDFCBANK', 'ICICIBANK', 'SUNPHARMA', 'MARUTI', 'BRITANNIA', 'TITAN', 'DIVISLAB', 'HEROMOTOCO', 'ONGC', 'ITC', 'BAJFINANCE', 'HCLTECH', 'AXISBANK', 'APOLLOHOSP', 'NESTLEIND']

# %%
ticker_list=nifty_50_tickers

# %%
print(ticker_list)
# Out:
# ['NIFTY 50', 'POWERGRID', 'BPCL', 'BHARTIARTL', 'HINDALCO', 'GRASIM', 'M&M', 'ADANIPORTS', 'HDFCLIFE', 'LT', 'TATASTEEL', 'TCS', 'LTIM', 'EICHERMOT', 'TATACONSUM', 'SHRIRAMFIN', 'SBILIFE', 'BAJAJ-AUTO', 'JSWSTEEL', 'DRREDDY', 'KOTAKBANK', 'INFY', 'ASIANPAINT', 'ADANIENT', 'INDUSINDBK', 'WIPRO', 'RELIANCE', 'COALINDIA', 'CIPLA', 'BAJAJFINSV', 'SBIN', 'HINDUNILVR', 'ULTRACEMCO', 'NTPC', 'TATAMOTORS', 'TECHM', 'HDFCBANK', 'ICICIBANK', 'SUNPHARMA', 'MARUTI', 'BRITANNIA', 'TITAN', 'DIVISLAB', 'HEROMOTOCO', 'ONGC', 'ITC', 'BAJFINANCE', 'HCLTECH', 'AXISBANK', 'APOLLOHOSP', 'NESTLEIND']

# %%
pip install finrl
# Out:
# Requirement already satisfied: finrl in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.3.6)
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl (from finrl)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /private/var/folders/3z/6b2hp23s5sg2j9x4jt4hyh_80000gn/T/pip-install-gm7y7796/elegantrl_9516109544c041cfbc0b90c53b5b009a
#   Running command git clone --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /private/var/folders/3z/6b2hp23s5sg2j9x4jt4hyh_80000gn/T/pip-install-gm7y7796/elegantrl_9516109544c041cfbc0b90c53b5b009a
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit b64df20f552477f24ec50c3e5088c1e241fdc455
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl) (3.2.0)
# Requirement already satisfied: ccxt<4,>=3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl) (3.1.60)
# Requirement already satisfied: exchange-calendars<5,>=4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl) (4.5.3)
# Requirement already satisfied: jqdatasdk<2,>=1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl) (1.9.3)
# Requirement already satisfied: pyfolio<0.10,>=0.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl) (0.9.2+75.g4b901f6)
# Requirement already satisfied: pyportfolioopt<2,>=1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl) (1.5.5)
# Requirement already satisfied: ray<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl) (2.10.0)
# Requirement already satisfied: scikit-learn<2,>=1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl) (1.4.1.post1)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (2.3.0a4)
# Requirement already satisfied: stockstats<0.6,>=0.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl) (0.5.4)
# Requirement already satisfied: wrds<4,>=3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl) (3.2.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from finrl) (0.2.37)
# Requirement already satisfied: pandas>=0.18.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl) (2.2.1)
# Requirement already satisfied: numpy>=1.11.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl) (1.26.4)
# Requirement already satisfied: requests<3,>2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl) (2.31.0)
# Requirement already satisfied: urllib3<2,>1.24 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl) (1.26.18)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl) (1.7.0)
# Requirement already satisfied: websockets<11,>=9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl) (10.4)
# Requirement already satisfied: msgpack==1.0.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl) (1.0.3)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl) (3.9.3)
# Requirement already satisfied: PyYAML==6.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl) (2.1.0)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl) (23.2)
# Requirement already satisfied: setuptools>=60.9.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ccxt<4,>=3->finrl) (69.2.0)
# Requirement already satisfied: certifi>=2018.1.18 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ccxt<4,>=3->finrl) (2024.2.2)
# Requirement already satisfied: cryptography>=2.6.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ccxt<4,>=3->finrl) (42.0.5)
# Requirement already satisfied: aiodns>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ccxt<4,>=3->finrl) (3.1.1)
# Requirement already satisfied: yarl>=1.7.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ccxt<4,>=3->finrl) (1.9.4)
# Requirement already satisfied: pyluach in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl) (2.2.0)
# Requirement already satisfied: toolz in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl) (0.12.1)
# Requirement already satisfied: tzdata in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl) (2024.1)
# Requirement already satisfied: korean-lunar-calendar in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl) (0.3.1)
# Requirement already satisfied: six in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from jqdatasdk<2,>=1->finrl) (1.16.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl) (2.0.29)
# Requirement already satisfied: thriftpy2>=0.3.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl) (0.4.20)
# Requirement already satisfied: pymysql>=0.7.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl) (1.1.0)
# Requirement already satisfied: ipython>=3.2.3 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from pyfolio<0.10,>=0.9->finrl) (8.22.2)
# Requirement already satisfied: matplotlib>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl) (3.8.3)
# Requirement already satisfied: pytz>=2014.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl) (2024.1)
# Requirement already satisfied: scipy>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl) (1.12.0)
# Requirement already satisfied: seaborn>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl) (0.13.2)
# Requirement already satisfied: empyrical>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl) (0.5.5)
# Requirement already satisfied: cvxpy<2.0.0,>=1.1.19 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyportfolioopt<2,>=1->finrl) (1.4.2)
# Requirement already satisfied: click>=7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl) (8.1.7)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl) (3.13.3)
# Requirement already satisfied: jsonschema in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl) (4.21.1)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl) (4.25.3)
# Requirement already satisfied: aiosignal in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl) (1.3.1)
# Requirement already satisfied: frozenlist in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl) (1.4.1)
# Requirement already satisfied: aiohttp-cors in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl) (0.7.0)
# Requirement already satisfied: colorful in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl) (0.3.14)
# Requirement already satisfied: opencensus in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl) (0.11.4)
# Requirement already satisfied: pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl) (2.6.4)
# Requirement already satisfied: prometheus-client>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl) (0.20.0)
# Requirement already satisfied: smart-open in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl) (7.0.4)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl) (20.25.1)
# Requirement already satisfied: grpcio>=1.42.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl) (1.62.1)
# Requirement already satisfied: tensorboardX>=1.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl) (2.6.2.2)
# Requirement already satisfied: pyarrow>=6.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl) (15.0.2)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl) (2024.3.1)
# Requirement already satisfied: joblib>=1.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl) (3.4.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (0.29.1)
# Requirement already satisfied: torch>=1.13 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (2.2.2)
# Requirement already satisfied: cloudpickle in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (3.0.0)
# Requirement already satisfied: opencv-python in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (4.9.0.80)
# Requirement already satisfied: pygame in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (2.1.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (2.16.2)
# Requirement already satisfied: psutil in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (5.9.8)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (4.66.2)
# Requirement already satisfied: rich in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (13.7.1)
# Requirement already satisfied: shimmy~=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl) (1.3.0)
# Requirement already satisfied: pillow in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl) (10.2.0)
# Requirement already satisfied: autorom~=0.6.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl) (0.6.1)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from wrds<4,>=3->finrl) (2.9.9)
# Requirement already satisfied: multitasking>=0.0.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl) (5.1.0)
# Requirement already satisfied: appdirs>=1.4.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl) (1.1)
# Requirement already satisfied: gym in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl) (0.26.2)
# Requirement already satisfied: pycares>=4.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl) (4.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl) (4.0.3)
# Requirement already satisfied: AutoROM.accept-rom-license in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from autorom[accept-rom-license]~=0.6.1; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl) (0.6.1)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl) (2.5)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl) (1.16.0)
# Requirement already satisfied: osqp>=0.6.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl) (0.6.4)
# Requirement already satisfied: ecos>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl) (2.0.13)
# Requirement already satisfied: clarabel>=0.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl) (0.7.1)
# Requirement already satisfied: scs>=3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl) (3.2.4.post1)
# Requirement already satisfied: pybind11 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl) (2.12.0)
# Requirement already satisfied: pandas-datareader>=0.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl) (0.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (4.10.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (0.0.4)
# Requirement already satisfied: webencodings in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from html5lib>=1.1->yfinance<0.3,>=0.2->finrl) (0.5.1)
# Requirement already satisfied: decorator in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.19.1)
# Requirement already satisfied: matplotlib-inline in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (2.17.2)
# Requirement already satisfied: stack-data in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (5.14.2)
# Requirement already satisfied: exceptiongroup in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<3,>=2->finrl) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pydantic!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,<3->ray[default,tune]<3,>=2->finrl) (2.16.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl) (3.6)
# Requirement already satisfied: ale-py~=0.8.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl) (0.8.1)
# Requirement already satisfied: absl-py>=0.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl) (2.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl) (3.0.1)
# Requirement already satisfied: ply<4.0,>=3.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from thriftpy2>=0.3.9->jqdatasdk<2,>=1->finrl) (3.11)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (1.12)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (3.2.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (3.1.3)
# Requirement already satisfied: distlib<1,>=0.3.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl) (0.3.8)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl) (4.2.0)
# Requirement already satisfied: gym-notices>=0.0.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl) (0.0.8)
# Requirement already satisfied: box2d-py==2.3.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym[box2d]->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl) (2.3.5)
# Requirement already satisfied: swig==4.* in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from gym[box2d]->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl) (4.2.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl) (0.18.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl) (3.0.0)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from smart-open->ray[default,tune]<3,>=2->finrl) (1.16.0)
# Requirement already satisfied: importlib-resources in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from ale-py~=0.8.1->shimmy[atari]~=1.3.0; extra == "extra"->stable-baselines3[extra]>=2.0.0a5->finrl) (6.4.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (1.63.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (1.23.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (2.29.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl) (0.1.2)
# Requirement already satisfied: qdldl in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from osqp>=0.6.2->cvxpy<2.0.0,>=1.1.19->pyportfolioopt<2,>=1->finrl) (0.1.7.post0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl) (2.1.5)
# Requirement already satisfied: executing>=1.2.0 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl) (0.2.2)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from sympy->torch>=1.13->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl) (0.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from config import config

# %%
#ticker_list = config.NIFTY_50_TICKER

# %%
ticker_list = ['POWERGRID', 'BPCL', 'BHARTIARTL', 'HINDALCO', 'GRASIM', 'M&M', 'ADANIPORTS', 'HDFCLIFE', 'LT', 'TATASTEEL', 'TCS', 'LTIM', 'EICHERMOT', 'TATACONSUM', 'SHRIRAMFIN', 'SBILIFE', 'BAJAJ-AUTO', 'JSWSTEEL', 'DRREDDY', 'KOTAKBANK', 'INFY', 'ASIANPAINT', 'ADANIENT', 'INDUSINDBK', 'WIPRO', 'RELIANCE', 'COALINDIA', 'CIPLA', 'BAJAJFINSV', 'SBIN', 'HINDUNILVR', 'ULTRACEMCO', 'NTPC', 'TATAMOTORS', 'TECHM', 'HDFCBANK', 'ICICIBANK', 'SUNPHARMA', 'MARUTI', 'BRITANNIA', 'TITAN', 'DIVISLAB', 'HEROMOTOCO', 'ONGC', 'ITC', 'BAJFINANCE', 'HCLTECH', 'AXISBANK', 'APOLLOHOSP', 'NESTLEIND']

# Add ".NS" to each ticker using list comprehension
ticker_list = [ticker + ".NS" for ticker in ticker_list]

print(ticker_list)
# Out:
# ['POWERGRID.NS', 'BPCL.NS', 'BHARTIARTL.NS', 'HINDALCO.NS', 'GRASIM.NS', 'M&M.NS', 'ADANIPORTS.NS', 'HDFCLIFE.NS', 'LT.NS', 'TATASTEEL.NS', 'TCS.NS', 'LTIM.NS', 'EICHERMOT.NS', 'TATACONSUM.NS', 'SHRIRAMFIN.NS', 'SBILIFE.NS', 'BAJAJ-AUTO.NS', 'JSWSTEEL.NS', 'DRREDDY.NS', 'KOTAKBANK.NS', 'INFY.NS', 'ASIANPAINT.NS', 'ADANIENT.NS', 'INDUSINDBK.NS', 'WIPRO.NS', 'RELIANCE.NS', 'COALINDIA.NS', 'CIPLA.NS', 'BAJAJFINSV.NS', 'SBIN.NS', 'HINDUNILVR.NS', 'ULTRACEMCO.NS', 'NTPC.NS', 'TATAMOTORS.NS', 'TECHM.NS', 'HDFCBANK.NS', 'ICICIBANK.NS', 'SUNPHARMA.NS', 'MARUTI.NS', 'BRITANNIA.NS', 'TITAN.NS', 'DIVISLAB.NS', 'HEROMOTOCO.NS', 'ONGC.NS', 'ITC.NS', 'BAJFINANCE.NS', 'HCLTECH.NS', 'AXISBANK.NS', 'APOLLOHOSP.NS', 'NESTLEIND.NS']

# %%
pip install --upgrade pandas-datareader
# Out:
# Requirement already satisfied: pandas-datareader in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.10.0)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas-datareader) (5.1.0)
# Requirement already satisfied: pandas>=0.23 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas-datareader) (2.2.1)
# Requirement already satisfied: requests>=2.19.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=0.23->pandas-datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from pandas>=0.23->pandas-datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=0.23->pandas-datareader) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests>=2.19.0->pandas-datareader) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /Users/kshama/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import config  # Make sure you have config.py in your project directory

start_date = '2018-01-01'
end_date = '2024-02-28'



combined_df = pd.DataFrame()  # Initialize an empty DataFrame

for ticker in ticker_list:
    df = yf.download(ticker, start=start_date, end=end_date)
    df['Symbols'] = ticker  # Add a column for the ticker symbol
    df.reset_index(inplace=True)  # Reset index
    df = df[['Date', 'Symbols', 'Adj Close', 'High', 'Low', 'Close', 'Open', 'Volume']]  # Reorder columns
    combined_df = pd.concat([combined_df, df])

combined_df.reset_index(drop=True, inplace=True)  # Reset index for better organization
print(combined_df.head())  # Print first few rows of the combined DataFrame
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#         Date       Symbols  Adj Close        High         Low       Close  \
# 0 2018-01-01  POWERGRID.NS  79.861046  113.484406  111.965652  112.612526
# 1 2018-01-02  POWERGRID.NS  80.080437  113.512527  112.106277  112.921906
# 2 2018-01-03  POWERGRID.NS  80.439468  113.878151  112.837524  113.428154
# 3 2018-01-04  POWERGRID.NS  79.920876  114.103149  112.500031  112.696899
# 4 2018-01-05  POWERGRID.NS  80.279900  113.653152  112.837524  113.203156
#
#          Open   Volume
# 0  111.965652  6388017
# 1  113.203156  4383705
# 2  113.343781  8187397
# 3  113.625031  4204055
# 4  113.231277  4923559

# %%
print(type(combined_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df = combined_df.copy()

# %%
df.shape
# Out:
# (76050, 8)

# %%
df.head()
# Out:
#         Date       Symbols  Adj Close        High         Low       Close  \
# 0 2018-01-01  POWERGRID.NS  79.861046  113.484406  111.965652  112.612526
# 1 2018-01-02  POWERGRID.NS  80.080437  113.512527  112.106277  112.921906
# 2 2018-01-03  POWERGRID.NS  80.439468  113.878151  112.837524  113.428154
# 3 2018-01-04  POWERGRID.NS  79.920876  114.103149  112.500031  112.696899
# 4 2018-01-05  POWERGRID.NS  80.279900  113.653152  112.837524  113.203156
#
#          Open   Volume
# 0  111.965652  6388017
# 1  113.203156  4383705
# 2  113.343781  8187397
# 3  113.625031  4204055
# 4  113.231277  4923559

# %% [markdown]
# data = df.copy()

# %%
data = df.copy()

# %%
if 'Adj Close' in data.columns:
    data = data.drop(columns=['Adj Close'])

# %%
# Assuming 'data' is your DataFrame
data = data.rename(columns={'Date': 'date', 'Symbols': 'tic', 'High': 'high', 'Low': 'low', 'Close': 'close', 'Open': 'open', 'Volume': 'volume'})

# %%
data.head()
# Out:
#         date           tic        high         low       close        open  \
# 0 2018-01-01  POWERGRID.NS  113.484406  111.965652  112.612526  111.965652
# 1 2018-01-02  POWERGRID.NS  113.512527  112.106277  112.921906  113.203156
# 2 2018-01-03  POWERGRID.NS  113.878151  112.837524  113.428154  113.343781
# 3 2018-01-04  POWERGRID.NS  114.103149  112.500031  112.696899  113.625031
# 4 2018-01-05  POWERGRID.NS  113.653152  112.837524  113.203156  113.231277
#
#     volume
# 0  6388017
# 1  4383705
# 2  8187397
# 3  4204055
# 4  4923559

# %%
data.columns = ['date','tic','close','high','low','open','volume']

# %%
data.columns
# Out:
# Index(['date', 'tic', 'close', 'high', 'low', 'open', 'volume'], dtype='object')

# %% [markdown]
# ### 2.4 Clean the Data

# %%
# check for missing values
data.isna().sum()
# Out:
# date      0
# tic       0
# close     0
# high      0
# low       0
# open      0
# volume    0
# dtype: int64

# %%
# check if all tickers have the same number of data points

no_datasets = []
for i in ticker_list:
    no_data_points = data[data['tic']==i].shape[0]
    no_datasets.append((i,no_data_points))
    data_points_df = pd.DataFrame(no_datasets)

# %%
data_points_df.tail()
# Out:
#                 0     1
# 45  BAJFINANCE.NS  1521
# 46     HCLTECH.NS  1521
# 47    AXISBANK.NS  1521
# 48  APOLLOHOSP.NS  1521
# 49   NESTLEIND.NS  1521

# %%
# Plot a bar chart to check that all tickers have same number of data points
plt.subplots(figsize = (8, 4))
plt.bar(data_points_df[0], data_points_df[1],alpha=0.3)
plt.xticks(rotation=90)
plt.show()

# %%
# create a list for dates with all ticker data points
date_list = list(data[data['tic']=='TCS.NS'].date)
# filter with date list
data_filtered = data[data['date'].isin(date_list)]

# %%
data_filtered.head()
# Out:
#         date           tic       close        high         low        open  \
# 0 2018-01-01  POWERGRID.NS  113.484406  111.965652  112.612526  111.965652
# 1 2018-01-02  POWERGRID.NS  113.512527  112.106277  112.921906  113.203156
# 2 2018-01-03  POWERGRID.NS  113.878151  112.837524  113.428154  113.343781
# 3 2018-01-04  POWERGRID.NS  114.103149  112.500031  112.696899  113.625031
# 4 2018-01-05  POWERGRID.NS  113.653152  112.837524  113.203156  113.231277
#
#     volume
# 0  6388017
# 1  4383705
# 2  8187397
# 3  4204055
# 4  4923559

# %%
# check if all tickers have the same number of data points

no_datasets = []
for i in ticker_list:
    no_data_points = data_filtered[data_filtered['tic']==i].shape[0]
    no_datasets.append((i,no_data_points))
    data_points_df = pd.DataFrame(no_datasets)

# %%
print(data_points_df)
# Out:
#                 0     1
# 0    POWERGRID.NS  1521
# 1         BPCL.NS  1521
# 2   BHARTIARTL.NS  1521
# 3     HINDALCO.NS  1521
# 4       GRASIM.NS  1521
# 5          M&M.NS  1521
# 6   ADANIPORTS.NS  1521
# 7     HDFCLIFE.NS  1521
# 8           LT.NS  1521
# 9    TATASTEEL.NS  1521
# 10         TCS.NS  1521
# 11        LTIM.NS  1521
# 12   EICHERMOT.NS  1521
# 13  TATACONSUM.NS  1521
# 14  SHRIRAMFIN.NS  1521
# 15     SBILIFE.NS  1521
# 16  BAJAJ-AUTO.NS  1521
# 17    JSWSTEEL.NS  1521
# 18     DRREDDY.NS  1521
# 19   KOTAKBANK.NS  1521
# 20        INFY.NS  1521
# 21  ASIANPAINT.NS  1521
# 22    ADANIENT.NS  1521
# 23  INDUSINDBK.NS  1521
# 24       WIPRO.NS  1521
# 25    RELIANCE.NS  1521
# 26   COALINDIA.NS  1521
# 27       CIPLA.NS  1521
# 28  BAJAJFINSV.NS  1521
# 29        SBIN.NS  1521
# 30  HINDUNILVR.NS  1521
# 31  ULTRACEMCO.NS  1521
# 32        NTPC.NS  1521
# 33  TATAMOTORS.NS  1521
# 34       TECHM.NS  1521
# 35    HDFCBANK.NS  1521
# 36   ICICIBANK.NS  1521
# 37   SUNPHARMA.NS  1521
# 38      MARUTI.NS  1521
# 39   BRITANNIA.NS  1521
# 40       TITAN.NS  1521
# 41    DIVISLAB.NS  1521
# 42  HEROMOTOCO.NS  1521
# 43        ONGC.NS  1521
# 44         ITC.NS  1521
# 45  BAJFINANCE.NS  1521
# 46     HCLTECH.NS  1521
# 47    AXISBANK.NS  1521
# 48  APOLLOHOSP.NS  1521
# 49   NESTLEIND.NS  1521

# %%
# Plot a bar chart to check that all tickers have same number of data points
plt.subplots(figsize = (8, 4))
plt.bar(data_points_df[0], data_points_df[1],alpha=0.3)
plt.xticks(rotation=90)
plt.show()

# %%
data_filtered.head()
# Out:
#         date           tic       close        high         low        open  \
# 0 2018-01-01  POWERGRID.NS  113.484406  111.965652  112.612526  111.965652
# 1 2018-01-02  POWERGRID.NS  113.512527  112.106277  112.921906  113.203156
# 2 2018-01-03  POWERGRID.NS  113.878151  112.837524  113.428154  113.343781
# 3 2018-01-04  POWERGRID.NS  114.103149  112.500031  112.696899  113.625031
# 4 2018-01-05  POWERGRID.NS  113.653152  112.837524  113.203156  113.231277
#
#     volume
# 0  6388017
# 1  4383705
# 2  8187397
# 3  4204055
# 4  4923559

# %% [markdown]
# ### 2.5 Save the Data to csv

# %%
data_filtered.to_csv('datasets/data.csv', index=False)

# %% [markdown]
# ### 2.6 Create a Dataset for the Close Prices

# %%
# read the data from the saved csv file
df_prices = pd.read_csv('./datasets/data.csv')

# %%
# Reset the Index to tic and date
df_prices = df_prices.reset_index().set_index(['tic', 'date']).sort_index()

# Get the list of all the tickers
tic_list = list(set([i for i,j in df_prices.index]))

# Create an empty data frame for the close prices
df_close = pd.DataFrame()

# %%
len(tic_list)
# Out:
# 50

# %%
# Reset the Index to tic and date
df_prices = df_prices.reset_index().set_index(['tic', 'date']).sort_index()

# Get all the Close Prices
df_close = pd.DataFrame()

for ticker in tic_list:
    series = df_prices.xs(ticker).close
    df_close[ticker] = series
    
df_close = df_close.reset_index()

# %%
df_close.head()
# Out:
#          date  BRITANNIA.NS  AXISBANK.NS  TATASTEEL.NS  HEROMOTOCO.NS  \
# 0  2018-01-01   2387.000000   569.799988     70.064255    3810.000000
# 1  2018-01-02   2371.125000   568.599976     69.668869    3784.350098
# 2  2018-01-03   2354.975098   565.450012     70.264328    3764.399902
# 3  2018-01-04   2344.449951   565.000000     72.736679    3759.949951
# 4  2018-01-05   2339.750000   566.000000     74.018112    3758.699951
#
#    TATACONSUM.NS  HDFCLIFE.NS    GRASIM.NS  JSWSTEEL.NS  BAJAJ-AUTO.NS  ...  \
# 0     317.799988   399.799988  1165.166992   271.700012    3345.050049  ...
# 1     314.950012   398.000000  1149.529175   268.000000    3348.000000  ...
# 2     315.149994   398.299988  1144.798096   272.250000    3310.199951  ...
# 3     313.500000   401.950012  1170.844482   281.899994    3274.250000  ...
# 4     315.850006   412.000000  1214.172241   289.899994    3294.000000  ...
#
#    BHARTIARTL.NS  NESTLEIND.NS  APOLLOHOSP.NS  BAJFINANCE.NS     INFY.NS  \
# 0     484.966522    790.159973    1216.000000    1760.000000  522.250000
# 1     480.279999    792.304993    1212.000000    1739.699951  521.000000
# 2     473.610687    793.500000    1203.949951    1738.349976  515.799988
# 3     475.142822    790.219971    1188.449951    1758.250000  510.500000
# 4     488.932068    788.400024    1199.000000    1821.000000  513.200012
#
#       ONGC.NS  SUNPHARMA.NS  POWERGRID.NS  INDUSINDBK.NS  BAJAJFINSV.NS
# 0  195.699997    585.400024    113.484406    1655.949951     530.875000
# 1  197.500000    582.000000    113.512527    1647.000000     522.900024
# 2  197.399994    578.950012    113.878151    1650.000000     517.979980
# 3  200.000000    583.950012    114.103149    1652.500000     513.500000
# 4  200.949997    587.349976    113.653152    1703.000000     514.494995
#
# [5 rows x 51 columns]

# %%
# Get Discriptive statistics
df_close.describe().T
# Out:
#                 count         mean          std          min          25%  \
# BRITANNIA.NS   1521.0  3593.591138   694.560606  2310.250000  3095.000000
# AXISBANK.NS    1521.0   727.522323   169.490767   337.500000   622.500000
# TATASTEEL.NS   1521.0    82.848506    36.558740    26.795000    49.730000
# HEROMOTOCO.NS  1521.0  2922.975437   494.633584  1623.000000  2613.800049
# TATACONSUM.NS  1521.0   564.366536   265.089944   186.000000   281.250000
# HDFCLIFE.NS    1521.0   566.417818    98.611536   349.750000   496.750000
# GRASIM.NS      1521.0  1266.606398   461.540912   456.086517   830.896179
# JSWSTEEL.NS    1521.0   494.204669   221.445966   145.949997   289.899994
# BAJAJ-AUTO.NS  1521.0  3620.979219  1012.497308  1989.000000  2932.000000
# NTPC.NS        1521.0   144.942549    49.479551    79.599998   116.699997
# SBIN.NS        1521.0   398.848554   142.643159   153.199997   282.200012
# M&M.NS         1521.0   915.016930   345.111960   283.000000   660.700012
# HCLTECH.NS     1521.0   860.047403   315.490524   428.600006   541.775024
# SHRIRAMFIN.NS  1521.0  1284.950002   352.983490   505.250793  1098.047241
# ADANIENT.NS    1521.0  1213.830101  1184.226820    69.263008   152.000000
# DRREDDY.NS     1521.0  4001.851679  1168.389153  1963.449951  2746.949951
# ITC.NS         1521.0   284.693655    82.540073   152.000000   217.750000
# LTIM.NS        1521.0  3527.623444  1762.855022  1125.500000  1738.000000
# ADANIPORTS.NS  1521.0   587.178108   232.444138   235.800003   376.899994
# COALINDIA.NS   1521.0   215.795332    66.792385   112.449997   155.949997
# TITAN.NS       1521.0  1798.877741   844.959973   787.000000  1065.949951
# EICHERMOT.NS   1521.0  2691.242362   623.252233  1309.989990  2196.500000
# ICICIBANK.NS   1521.0   608.427548   240.551732   264.350006   373.750000
# BPCL.NS        1521.0   396.373833    62.097870   268.100006   350.799988
# SBILIFE.NS     1521.0   979.875937   258.162518   533.000000   732.500000
# HDFCBANK.NS    1521.0  1330.149028   244.004140   810.000000  1086.900024
# LT.NS          1521.0  1686.537276   609.259589   755.750000  1328.400024
# HINDALCO.NS    1521.0   328.704405   135.216904    91.449997   207.149994
# CIPLA.NS       1521.0   813.601545   252.778699   390.750000   577.900024
# DIVISLAB.NS    1521.0  2927.722648  1223.182100  1007.000000  1678.699951
# ASIANPAINT.NS  1521.0  2351.066203   806.039056  1109.949951  1514.000000
# TATAMOTORS.NS  1521.0   339.735503   184.907620    66.900002   177.850006
# TCS.NS         1521.0  2775.643223   739.629501  1331.000000  2085.500000
# KOTAKBANK.NS   1521.0  1626.023832   281.773944  1002.900024  1354.400024
# MARUTI.NS      1521.0  7966.867930  1342.281525  4267.000000  7050.000000
# TECHM.NS       1521.0   969.376331   292.969703   508.700012   720.000000
# HINDUNILVR.NS  1521.0  2186.717812   383.332167  1303.000000  1843.599976
# RELIANCE.NS    1521.0  1792.728959   587.669834   819.104980  1185.889526
# WIPRO.NS       1521.0   370.873236   137.699955   171.350006   249.000061
# ULTRACEMCO.NS  1521.0  5820.325023  1824.438645  3150.000000  4134.250000
# BHARTIARTL.NS  1521.0   583.895512   218.228107   261.364594   371.426483
# NESTLEIND.NS   1521.0  1653.481838   458.291280   703.320007  1181.770020
# APOLLOHOSP.NS  1521.0  2994.509636  1675.554523   941.000000  1354.000000
# BAJFINANCE.NS  1521.0  4948.463318  2023.699652  1617.500000  3044.000000
# INFY.NS        1521.0  1157.167702   420.649834   510.500000   730.299988
# ONGC.NS        1521.0   144.853386    38.828964    63.000000   121.449997
# SUNPHARMA.NS   1521.0   716.871533   267.139066   344.000000   485.000000
# POWERGRID.NS   1521.0   138.144567    39.221778    85.443771   108.984406
# INDUSINDBK.NS  1521.0  1240.157922   391.983951   324.000000   967.700012
# BAJAJFINSV.NS  1521.0  1094.413668   448.742607   427.695007   648.500000
#
#                        50%          75%           max
# BRITANNIA.NS   3518.000000  3900.000000   5386.049805
# AXISBANK.NS     735.000000   809.900024   1151.849976
# TATASTEEL.NS     72.736679   116.269997    153.449997
# HEROMOTOCO.NS  2831.699951  3139.600098   4949.049805
# TATACONSUM.NS   612.400024   782.900024   1190.949951
# HDFCLIFE.NS     578.000000   645.900024    775.650024
# GRASIM.NS      1238.973633  1696.753296   2244.000000
# JSWSTEEL.NS     412.350006   704.849976    895.750000
# BAJAJ-AUTO.NS  3372.449951  3898.899902   8650.000000
# NTPC.NS         134.149994   161.649994    348.049988
# SBIN.NS         361.500000   529.950012    777.500000
# M&M.NS          811.750000  1184.199951   1956.949951
# HCLTECH.NS      926.950012  1122.699951   1697.349976
# SHRIRAMFIN.NS  1266.659058  1419.900024   2535.000000
# ADANIENT.NS     552.950012  2189.800049   4190.000000
# DRREDDY.NS     4350.000000  4885.000000   6494.049805
# ITC.NS          270.299988   316.000000    499.700012
# LTIM.NS        3864.899902  4924.250000   7588.799805
# ADANIPORTS.NS   548.700012   759.900024   1343.000000
# COALINDIA.NS    215.600006   253.850006    487.600006
# TITAN.NS       1493.000000  2521.550049   3886.949951
# EICHERMOT.NS   2704.000000  3140.000000   4200.000000
# ICICIBANK.NS    561.000000   841.700012   1070.000000
# BPCL.NS         385.299988   434.500000    687.950012
# SBILIFE.NS      972.599976  1196.949951   1569.000000
# HDFCBANK.NS    1381.949951  1537.250000   1757.500000
# LT.NS          1475.500000  1931.949951   3737.899902
# HINDALCO.NS     277.899994   445.250000    636.000000
# CIPLA.NS        825.000000   979.799988   1491.000000
# DIVISLAB.NS    3307.699951  3767.000000   5425.100098
# ASIANPAINT.NS  2520.000000  3127.949951   3590.000000
# TATAMOTORS.NS   319.750000   446.000000    965.000000
# TCS.NS         3055.850098  3392.949951   4184.750000
# KOTAKBANK.NS   1730.000000  1848.050049   2253.000000
# MARUTI.NS      7674.899902  8940.000000  11720.000000
# TECHM.NS        980.250000  1136.900024   1838.000000
# HINDUNILVR.NS  2249.000000  2508.000000   2859.300049
# RELIANCE.NS    1933.684326  2314.699951   2999.899902
# WIPRO.NS        379.799988   437.950012    739.849976
# ULTRACEMCO.NS  5535.000000  7299.000000  10526.000000
# BHARTIARTL.NS   543.397705   755.950012   1200.650024
# NESTLEIND.NS   1735.000000  1944.989990   2769.300049
# APOLLOHOSP.NS  2745.000000  4582.450195   6874.450195
# BAJFINANCE.NS  5166.000000  6993.500000   8192.000000
# INFY.NS        1274.000000  1519.949951   1953.900024
# ONGC.NS         148.750000   169.899994    281.149994
# SUNPHARMA.NS    627.900024   924.750000   1585.449951
# POWERGRID.NS    120.093781   164.399994    293.399994
# INDUSINDBK.NS  1220.000000  1521.949951   2038.000000
# BAJAJFINSV.NS   970.900024  1566.000000   1932.500000

# %%
# Save the Close Price datase

df_close.to_csv('datasets/close_prices.csv', index=False)

# %%
# Close prices for all the stocks
df_close_full_stocks = df_close

# %%
df_close_full_stocks.head()
# Out:
#          date  BRITANNIA.NS  AXISBANK.NS  TATASTEEL.NS  HEROMOTOCO.NS  \
# 0  2018-01-01   2387.000000   569.799988     70.064255    3810.000000
# 1  2018-01-02   2371.125000   568.599976     69.668869    3784.350098
# 2  2018-01-03   2354.975098   565.450012     70.264328    3764.399902
# 3  2018-01-04   2344.449951   565.000000     72.736679    3759.949951
# 4  2018-01-05   2339.750000   566.000000     74.018112    3758.699951
#
#    TATACONSUM.NS  HDFCLIFE.NS    GRASIM.NS  JSWSTEEL.NS  BAJAJ-AUTO.NS  ...  \
# 0     317.799988   399.799988  1165.166992   271.700012    3345.050049  ...
# 1     314.950012   398.000000  1149.529175   268.000000    3348.000000  ...
# 2     315.149994   398.299988  1144.798096   272.250000    3310.199951  ...
# 3     313.500000   401.950012  1170.844482   281.899994    3274.250000  ...
# 4     315.850006   412.000000  1214.172241   289.899994    3294.000000  ...
#
#    BHARTIARTL.NS  NESTLEIND.NS  APOLLOHOSP.NS  BAJFINANCE.NS     INFY.NS  \
# 0     484.966522    790.159973    1216.000000    1760.000000  522.250000
# 1     480.279999    792.304993    1212.000000    1739.699951  521.000000
# 2     473.610687    793.500000    1203.949951    1738.349976  515.799988
# 3     475.142822    790.219971    1188.449951    1758.250000  510.500000
# 4     488.932068    788.400024    1199.000000    1821.000000  513.200012
#
#       ONGC.NS  SUNPHARMA.NS  POWERGRID.NS  INDUSINDBK.NS  BAJAJFINSV.NS
# 0  195.699997    585.400024    113.484406    1655.949951     530.875000
# 1  197.500000    582.000000    113.512527    1647.000000     522.900024
# 2  197.399994    578.950012    113.878151    1650.000000     517.979980
# 3  200.000000    583.950012    114.103149    1652.500000     513.500000
# 4  200.949997    587.349976    113.653152    1703.000000     514.494995
#
# [5 rows x 51 columns]

# %%
pip install pickleshare
# Out:
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.7.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %store df_close_full_stocks
# Out:
# Stored 'df_close_full_stocks' (DataFrame)

# %%
ticker_list = df_close_full_stocks.columns

# %%
print(ticker_list)
# Out:
# Index(['date', 'BRITANNIA.NS', 'AXISBANK.NS', 'TATASTEEL.NS', 'HEROMOTOCO.NS',
#        'TATACONSUM.NS', 'HDFCLIFE.NS', 'GRASIM.NS', 'JSWSTEEL.NS',
#        'BAJAJ-AUTO.NS', 'NTPC.NS', 'SBIN.NS', 'M&M.NS', 'HCLTECH.NS',
#        'SHRIRAMFIN.NS', 'ADANIENT.NS', 'DRREDDY.NS', 'ITC.NS', 'LTIM.NS',
#        'ADANIPORTS.NS', 'COALINDIA.NS', 'TITAN.NS', 'EICHERMOT.NS',
#        'ICICIBANK.NS', 'BPCL.NS', 'SBILIFE.NS', 'HDFCBANK.NS', 'LT.NS',
#        'HINDALCO.NS', 'CIPLA.NS', 'DIVISLAB.NS', 'ASIANPAINT.NS',
#        'TATAMOTORS.NS', 'TCS.NS', 'KOTAKBANK.NS', 'MARUTI.NS', 'TECHM.NS',
#        'HINDUNILVR.NS', 'RELIANCE.NS', 'WIPRO.NS', 'ULTRACEMCO.NS',
#        'BHARTIARTL.NS', 'NESTLEIND.NS', 'APOLLOHOSP.NS', 'BAJFINANCE.NS',
#        'INFY.NS', 'ONGC.NS', 'SUNPHARMA.NS', 'POWERGRID.NS', 'INDUSINDBK.NS',
#        'BAJAJFINSV.NS'],
#       dtype='object')
