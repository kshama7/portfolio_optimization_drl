# %% [markdown]
# # Portfolio Optimization using Deep Reinforcement Learning
# ---

# %% [markdown]
# ## 8.0 Deep Reinforcement Learning Portfolios

# %% [markdown]
# ### 8.1 Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pylab as plt
matplotlib.use('Agg')
import datetime

from pypfopt.efficient_frontier import efficient_frontier
from pypfopt.efficient_frontier.efficient_frontier import EfficientFrontier
from pypfopt import efficient_frontier
from pypfopt import risk_models
from pypfopt import expected_returns

# %%
import finrl

# %%
# Imports from the FinRL Library

from finrl import config
from backtest import BackTestStats, BaselineStats, BackTestPlot, backtest_strat, baseline_strat
from backtest import backtest_strat, baseline_strat
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# ### 8.2 Load Data

# %%
# %store -r train_df
# %store -r test_df

# %%
tech_indicator_list = ['f01','f02','f03','f04']

# %%
train_df.head()
# Out:
#          date            tic        close         high          low  \
# 0  2019-01-09  ASIANPAINT.NS  1414.000000  1397.150024  1402.000000
# 0  2019-01-09  BAJAJ-AUTO.NS  2710.000000  2672.500000  2696.899902
# 0  2019-01-09      GRASIM.NS   840.956177   823.226685   831.991821
# 0  2019-01-09     HCLTECH.NS   474.274994   466.149994   469.200012
# 0  2019-01-09    HDFCBANK.NS  1060.675049  1051.300049  1058.400024
#
#           open   volume                                           cov_list  \
# 0  1402.500000   973687  [[0.00015852269746834745, 1.720325697910041e-0...
# 0  2702.500000   285560  [[0.00015852269746834745, 1.720325697910041e-0...
# 0   836.673218  4021049  [[0.00015852269746834745, 1.720325697910041e-0...
# 0   473.500000  2471720  [[0.00015852269746834745, 1.720325697910041e-0...
# 0  1059.000000  4284314  [[0.00015852269746834745, 1.720325697910041e-0...
#
#        f01       f02  f03      f04
# 0  1.47337  0.150646  0.0  4.06108
# 0  1.47337  0.150646  0.0  4.06108
# 0  1.47337  0.150646  0.0  4.06108
# 0  1.47337  0.150646  0.0  4.06108
# 0  1.47337  0.150646  0.0  4.06108

# %%
train_df.shape
# Out:
# (20300, 12)

# %% [markdown]
# ### 8.4 Implement DRL Algorithms

# %%
from finrl.agents.elegantrl.models import DRLAgent
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv

# %%
import env_portfolio
from env_portfolio import StockPortfolioEnv

import train_models
from train_models import DRLAgents

# %%
stock_dimension = len(train_df.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 20, State Space: 20

# %%
weights_initial = [1/stock_dimension]*stock_dimension

# %%
env_kwargs = {
    "hmax": 500, 
    "initial_amount": 1000000, 
    "transaction_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": tech_indicator_list, 
    "action_space": stock_dimension, 
    "reward_scaling": 0,
    'initial_weights': [1/stock_dimension]*stock_dimension
}

# %%
e_train_gym = StockPortfolioEnv(df = train_df, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %% [markdown]
# #### 8.4.1 Model 1: A2C: Advantage Actor-Critic

# %%
import env_portfolio
from env_portfolio import StockPortfolioEnv

import train_models
from train_models import DRLAgents

# %%
train_df.head()
# Out:
#          date            tic        close         high          low  \
# 0  2019-01-09  ASIANPAINT.NS  1414.000000  1397.150024  1402.000000
# 0  2019-01-09  BAJAJ-AUTO.NS  2710.000000  2672.500000  2696.899902
# 0  2019-01-09      GRASIM.NS   840.956177   823.226685   831.991821
# 0  2019-01-09     HCLTECH.NS   474.274994   466.149994   469.200012
# 0  2019-01-09    HDFCBANK.NS  1060.675049  1051.300049  1058.400024
#
#           open   volume                                           cov_list  \
# 0  1402.500000   973687  [[0.00015852269746834745, 1.720325697910041e-0...
# 0  2702.500000   285560  [[0.00015852269746834745, 1.720325697910041e-0...
# 0   836.673218  4021049  [[0.00015852269746834745, 1.720325697910041e-0...
# 0   473.500000  2471720  [[0.00015852269746834745, 1.720325697910041e-0...
# 0  1059.000000  4284314  [[0.00015852269746834745, 1.720325697910041e-0...
#
#        f01       f02  f03      f04
# 0  1.47337  0.150646  0.0  4.06108
# 0  1.47337  0.150646  0.0  4.06108
# 0  1.47337  0.150646  0.0  4.06108
# 0  1.47337  0.150646  0.0  4.06108
# 0  1.47337  0.150646  0.0  4.06108

# %%
train_df.to_excel('train.xlsx', sheet_name="train_df", index=False, header=True)

# %%
from train_models import DRLAgents

# %%
# initialize
agent = DRLAgents(env=env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                                tb_log_name='a2c',
                                total_timesteps=50000)
# Out:
# Logging to tensorboard_log/a2c/a2c_127
# -------------------------------------
# | time/                 |           |
# |    fps                | 1550      |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -28.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 99        |
# |    policy_loss        | 1.29e+08  |
# |    std                | 0.997     |
# |    value_loss         | 2.31e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1615     |
# |    iterations         | 200      |
# |    time_elapsed       | 0        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -28.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 199      |
# |    policy_loss        | 1.43e+08 |
# |    std                | 0.997    |
# |    value_loss         | 3.54e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1831765.7026804532
# Sharpe:  1.0559598264058734
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 1268     |
# |    iterations         | 300      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -28.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 299      |
# |    policy_loss        | 1.32e+08 |
# |    std                | 0.996    |
# |    value_loss         | 2.41e+13 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1343      |
# |    iterations         | 400       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -28.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 399       |
# |    policy_loss        | 1.59e+08  |
# |    std                | 0.996     |
# |    value_loss         | 4.41e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2024046.6802712074
# Sharpe:  1.2313907909487345
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1314      |
# |    iterations         | 500       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -28.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 499       |
# |    policy_loss        | 1.15e+08  |
# |    std                | 0.995     |
# |    value_loss         | 1.99e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1360     |
# |    iterations         | 600      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -28.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 599      |
# |    policy_loss        | 1.84e+08 |
# |    std                | 0.994    |
# |    value_loss         | 4.17e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1885352.3952104033
# Sharpe:  1.1204786530563386
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 1364     |
# |    iterations         | 700      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -28.3    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 699      |
# |    policy_loss        | 9.23e+07 |
# |    std                | 0.994    |
# |    value_loss         | 1.48e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1397     |
# |    iterations         | 800      |
# |    time_elapsed       | 2        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 799      |
# |    policy_loss        | 1.38e+08 |
# |    std                | 0.992    |
# |    value_loss         | 3.28e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1725428.1596745895
# Sharpe:  0.9673688317636523
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 1394     |
# |    iterations         | 900      |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 899      |
# |    policy_loss        | 9.53e+07 |
# |    std                | 0.991    |
# |    value_loss         | 1.48e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1420     |
# |    iterations         | 1000     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 999      |
# |    policy_loss        | 1.44e+08 |
# |    std                | 0.991    |
# |    value_loss         | 3.24e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1779713.021159797
# Sharpe:  1.006064839290997
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 1413     |
# |    iterations         | 1100     |
# |    time_elapsed       | 3        |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 1099     |
# |    policy_loss        | 8.94e+07 |
# |    std                | 0.991    |
# |    value_loss         | 1.38e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1437     |
# |    iterations         | 1200     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 1199     |
# |    policy_loss        | 1.45e+08 |
# |    std                | 0.99     |
# |    value_loss         | 3.24e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1779867.906018119
# Sharpe:  1.013628719598972
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 1422     |
# |    iterations         | 1300     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 6500     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 1299     |
# |    policy_loss        | 1.11e+08 |
# |    std                | 0.99     |
# |    value_loss         | 1.37e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1436     |
# |    iterations         | 1400     |
# |    time_elapsed       | 4        |
# |    total_timesteps    | 7000     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 1399     |
# |    policy_loss        | 1.57e+08 |
# |    std                | 0.99     |
# |    value_loss         | 3.71e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1848281.6637870478
# Sharpe:  1.073310804087157
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 1425     |
# |    iterations         | 1500     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 1499     |
# |    policy_loss        | 1.03e+08 |
# |    std                | 0.989    |
# |    value_loss         | 1.56e+13 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1442     |
# |    iterations         | 1600     |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -28.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 1599     |
# |    policy_loss        | 1.6e+08  |
# |    std                | 0.989    |
# |    value_loss         | 4.02e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1941882.6703467516
# Sharpe:  1.1624874037495587
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1439      |
# |    iterations         | 1700      |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -28.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1699      |
# |    policy_loss        | 9.97e+07  |
# |    std                | 0.987     |
# |    value_loss         | 1.43e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 1456      |
# |    iterations         | 1800      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -28.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1799      |
# |    policy_loss        | 1.45e+08  |
# |    std                | 0.986     |
# |    value_loss         | 3.33e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1905201.515107819
# Sharpe:  1.1307515094650815
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 1448      |
# |    iterations         | 1900      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -28.1     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1899      |
# |    policy_loss        | 8.19e+07  |
# |    std                | 0.984     |
# |    value_loss         | 1.22e+13  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 1460     |
# |    iterations         | 2000     |
# |    time_elapsed       | 6        |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -28.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 1999     |
# |    policy_loss        | 1.51e+08 |
# |    std                | 0.985    |
# |    value_loss         | 2.97e+13 |
# ------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:
|
# |    explained_variance | 1.79e-07 |
# |    learning_rate      | 0.0002   |
# |    n_updates          | 9999     |
# |    policy_loss        | 9.98e+07 |
# |    std                | 0.948    |
# |    value_loss         | 1.53e+13 |
# ------------------------------------

# %% [markdown]
# #### 8.4.2 Model 2: PPO : Proximal Policy Optimization

# %%
agent = DRLAgents(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.005,
    "learning_rate": 0.0001,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.0001, 'batch_size': 128}
# Using cpu device

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=50000)
# Out:
# Logging to tensorboard_log/ppo/ppo_8
# =================================
# begin_total_asset:1000000
# end_total_asset:1735992.762826523
# Sharpe:  0.967328971383132
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1782458.9134549478
# Sharpe:  1.0132703318306215
# =================================
# -----------------------------
# | time/              |      |
# |    fps             | 2437 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1848063.5215638904
# Sharpe:  1.0695004672535804
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2024231.015839269
# Sharpe:  1.2187809726347039
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 2136      |
# |    iterations           | 2         |
# |    time_elapsed         | 1         |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.68e+14  |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -3.19e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.39e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1863353.7654932563
# Sharpe:  1.0947020116563417
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1829219.3269588228
# Sharpe:  1.0651803820669552
# =================================
# --------------------------------------
# | time/                   |          |
# |    fps                  | 2062     |
# |    iterations           | 3        |
# |    time_elapsed         | 2        |
# |    total_timesteps      | 6144     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -28.4    |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0001   |
# |    loss                 | 3.46e+14 |
# |    n_updates            | 20       |
# |    policy_gradient_loss | -3.5e-07 |
# |    std                  | 1        |
# |    value_loss           | 6.47e+14 |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1884957.3329050469
# Sharpe:  1.112279881984519
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1875645.2277319578
# Sharpe:  1.0994105552123083
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 2022      |
# |    iterations           | 4         |
# |    time_elapsed         | 4         |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.8e+14   |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -6.83e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.88e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1789819.001162078
# Sharpe:  1.0215777700862307
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1719303.6619328025
# Sharpe:  0.957863935096554
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 2001      |
# |    iterations           | 5         |
# |    time_elapsed         | 5         |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 3.14e+14  |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -8.17e-07 |
# |    std                  | 1         |
# |    value_loss           | 6.12e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1831894.148683995
# Sharpe:  1.0671306361527049
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1774887.0366254314
# Sharpe:  1.0004478180604155
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1993      |
# |    iterations           | 6         |
# |    time_elapsed         | 6         |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.76e+14  |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -6.54e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.45e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1789438.0010992005
# Sharpe:  1.0283379757291087
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1739656.2869702321
# Sharpe:  0.9729076377255892
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1982      |
# |    iterations           | 7         |
# |    time_elapsed         | 7         |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.93e+14  |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -4.61e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.51e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1800678.217329657
# Sharpe:  1.0327146185601326
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1801834.5374093351
# Sharpe:  1.0437554232389434
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1976      |
# |    iterations           | 8         |
# |    time_elapsed         | 8         |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.72e+14  |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -4.99e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.4e+14   |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1712589.3441533525
# Sharpe:  0.9474258222438497
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1840046.3657697302
# Sharpe:  1.057991499655714
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1974      |
# |    iterations           | 9         |
# |    time_elapsed         | 9         |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.85e+14  |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -4.52e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.63e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1915550.2383235863
# Sharpe:  1.1270646755016231
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1848342.4463925904
# Sharpe:  1.0761926580554613
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1943      |
# |    iterations           | 10        |
# |    time_elapsed         | 10        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.98e+14  |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -4.54e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.53e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1949635.9774401367
# Sharpe:  1.1413394862230657
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1873225.0282894664
# Sharpe:  1.0968410069601962
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1942      |
# |    iterations           | 11        |
# |    time_elapsed         | 11        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.95e+14  |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -3.85e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.93e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1824271.2291379895
# Sharpe:  1.052284754353013
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1654070.1172807445
# Sharpe:  0.8950980317393206
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1935      |
# |    iterations           | 12        |
# |    time_elapsed         | 12        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 3.22e+14  |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -4.33e-07 |
# |    std                  | 1         |
# |    value_loss           | 6.22e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1962846.3244492272
# Sharpe:  1.1753317311368534
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1721229.9057188649
# Sharpe:  0.9622484538044356
# =================================
# --------------------------------------
# | time/                   |          |
# |    fps                  | 1931     |
# |    iterations           | 13       |
# |    time_elapsed         | 13       |
# |    total_timesteps      | 26624    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -28.4    |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0001   |
# |    loss                 | 2.56e+14 |
# |    n_updates            | 120      |
# |    policy_gradient_loss | -5e-07   |
# |    std                  | 1        |
# |    value_loss           | 5.37e+14 |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1988085.1766937536
# Sharpe:  1.1778202653658991
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1924041.7700826332
# Sharpe:  1.1369450016236635
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1927      |
# |    iterations           | 14        |
# |    time_elapsed         | 14        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.84e+14  |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -5.28e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.85e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1944763.7692508383
# Sharpe:  1.1702023247707163
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1906546.0298037662
# Sharpe:  1.1182907676678457
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1928      |
# |    iterations           | 15        |
# |    time_elapsed         | 15        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 3.23e+14  |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -4.87e-07 |
# |    std                  | 1         |
# |    value_loss           | 6.29e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1860173.8209533875
# Sharpe:  1.0783500627130043
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1858652.2788188804
# Sharpe:  1.097082542593279
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1926      |
# |    iterations           | 16        |
# |    time_elapsed         | 17        |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 3.09e+14  |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -7.28e-07 |
# |    std                  | 1         |
# |    value_loss           | 6.07e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1773385.3820379118
# Sharpe:  1.0077787824177762
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1815169.3048060387
# Sharpe:  1.0390694114751198
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1923      |
# |    iterations           | 17        |
# |    time_elapsed         | 18        |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.74e+14  |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -4.33e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.71e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1855515.2233364102
# Sharpe:  1.0728633412243487
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1788960.5650291182
# Sharpe:  1.0219418066625994
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1920      |
# |    iterations           | 18        |
# |    time_elapsed         | 19        |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.67e+14  |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -4.54e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.49e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1815544.8992895365
# Sharpe:  1.0471341887520573
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1782479.1222131997
# Sharpe:  1.004172327048002
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1917      |
# |    iterations           | 19        |
# |    time_elapsed         | 20        |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.97e+14  |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -5.13e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.66e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1806450.7859918445
# Sharpe:  1.0334800807305842
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1821150.9210127795
# Sharpe:  1.0508054685247294
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1919      |
# |    iterations           | 20        |
# |    time_elapsed         | 21        |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.87e+14  |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -2.65e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.68e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1793456.0867933256
# Sharpe:  1.0181543591276527
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1879104.1463117697
# Sharpe:  1.0957421720231357
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1906      |
# |    iterations           | 21        |
# |    time_elapsed         | 22        |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.75e+14  |
# |    n_updates            | 200       |
# |    policy_gradient_loss | -5.18e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.71e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1813360.778625613
# Sharpe:  1.037701678506758
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1886593.2215815766
# Sharpe:  1.1010465556187663
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1904      |
# |    iterations           | 22        |
# |    time_elapsed         | 23        |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.65e+14  |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -6.93e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.59e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1794594.9521565526
# Sharpe:  1.028855397770651
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1764105.338395136
# Sharpe:  1.0097666690542701
# =================================
# --------------------------------------
# | time/                   |          |
# |    fps                  | 1902     |
# |    iterations           | 23       |
# |    time_elapsed         | 24       |
# |    total_timesteps      | 47104    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -28.4    |
# |    explained_variance   | 0        |
# |    learning_rate        | 0.0001   |
# |    loss                 | 2.77e+14 |
# |    n_updates            | 220      |
# |    policy_gradient_loss | -6.5e-07 |
# |    std                  | 1        |
# |    value_loss           | 5.72e+14 |
# --------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1923020.1089519337
# Sharpe:  1.1312713505292071
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1876980.5487630984
# Sharpe:  1.0933163053552455
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1900      |
# |    iterations           | 24        |
# |    time_elapsed         | 25        |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 2.77e+14  |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -7.87e-07 |
# |    std                  | 1         |
# |    value_loss           | 5.52e+14  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1932100.322800576
# Sharpe:  1.151265272783163
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2099541.87834907
# Sharpe:  1.2768917540874634
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 1903      |
# |    iterations           | 25        |
# |    time_elapsed         | 26        |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -28.4     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 3.12e+14  |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -6.72e-07 |
# |    std                  | 1         |
# |    value_loss           | 6.13e+14  |
# ---------------------------------------

# %% [markdown]
# #### 8.4.3 Model 3: DDPG : Deep Deterministic Policy Gradient

# %%
agent = DRLAgents(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}


model_ddpg = agent.get_model("ddpg",model_kwargs = DDPG_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# Logging to tensorboard_log/ddpg/ddpg_6
# =================================
# begin_total_asset:1000000
# end_total_asset:1906019.2483081822
# Sharpe:  1.1458286025228233
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 150       |
# |    time_elapsed    | 26        |
# |    total_timesteps | 4060      |
# | train/             |           |
# |    actor_loss      | -2.27e+07 |
# |    critic_loss     | 7.96e+11  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3959      |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 150      |
# |    time_elapsed    | 53       |
# |    total_timesteps | 8120     |
# | train/             |          |
# |    actor_loss      | -4.4e+07 |
# |    critic_loss     | 2.67e+12 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8019     |
# ---------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 152       |
# |    time_elapsed    | 79        |
# |    total_timesteps | 12180     |
# | train/             |           |
# |    actor_loss      | -6.06e+07 |
# |    critic_loss     | 3.64e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12079     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 153       |
# |    time_elapsed    | 105       |
# |    total_timesteps | 16240     |
# | train/             |           |
# |    actor_loss      | -7.48e+07 |
# |    critic_loss     | 5.24e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16139     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 150       |
# |    time_elapsed    | 135       |
# |    total_timesteps | 20300     |
# | train/             |           |
# |    actor_loss      | -8.55e+07 |
# |    critic_loss     | 6.63e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20199     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 151       |
# |    time_elapsed    | 160       |
# |    total_timesteps | 24360     |
# | train/             |           |
# |    actor_loss      | -9.48e+07 |
# |    critic_loss     | 8.02e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24259     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 152       |
# |    time_elapsed    | 186       |
# |    total_timesteps | 28420     |
# | train/             |           |
# |    actor_loss      | -1.02e+08 |
# |    critic_loss     | 5.77e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 28319     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 153       |
# |    time_elapsed    | 212       |
# |    total_timesteps | 32480     |
# | train/             |           |
# |    actor_loss      | -1.07e+08 |
# |    critic_loss     | 7.24e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32379     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 153       |
# |    time_elapsed    | 238       |
# |    total_timesteps | 36540     |
# | train/             |           |
# |    actor_loss      | -1.13e+08 |
# |    critic_loss     | 7.58e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36439     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 153       |
# |    time_elapsed    | 264       |
# |    total_timesteps | 40600     |
# | train/             |           |
# |    actor_loss      | -1.16e+08 |
# |    critic_loss     | 6.77e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 40499     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 149       |
# |    time_elapsed    | 297       |
# |    total_timesteps | 44660     |
# | train/             |           |
# |    actor_loss      | -1.19e+08 |
# |    critic_loss     | 1.19e+14  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 44559     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 148      |
# |    time_elapsed    | 329      |
# |    total_timesteps | 48720    |
# | train/             |          |
# |    actor_loss      | -1.2e+08 |
# |    critic_loss     | 9.39e+12 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 48619    |
# ---------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================

# %% [markdown]
# #### 8.4.4 Model 4: SAC : Soft Actor-Critic

# %%
agent = DRLAgents(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0003,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0003, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=50000)
# Out:
# Logging to tensorboard_log/sac/sac_5
# =================================
# begin_total_asset:1000000
# end_total_asset:1868735.1478745686
# Sharpe:  1.0901952475838916
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826751.7565411686
# Sharpe:  1.0550710004492392
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826751.5464523996
# Sharpe:  1.055070361193
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826752.0876221845
# Sharpe:  1.0550709743703564
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 131       |
# |    time_elapsed    | 30        |
# |    total_timesteps | 4060      |
# | train/             |           |
# |    actor_loss      | -8.53e+06 |
# |    critic_loss     | 7.7e+11   |
# |    ent_coef        | 0.379     |
# |    ent_coef_loss   | 199       |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 3959      |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.494671965
# Sharpe:  1.055069577735394
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826749.1735419852
# Sharpe:  1.0550682761707861
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826749.922244525
# Sharpe:  1.0550688471457543
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.5826053051
# Sharpe:  1.055069408675174
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 128      |
# |    time_elapsed    | 63       |
# |    total_timesteps | 8120     |
# | train/             |          |
# |    actor_loss      | -2.9e+07 |
# |    critic_loss     | 1.04e+12 |
# |    ent_coef        | 1.32     |
# |    ent_coef_loss   | -58.6    |
# |    learning_rate   | 0.0003   |
# |    n_updates       | 8019     |
# ---------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.4310074635
# Sharpe:  1.0550692453313648
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826746.6587121056
# Sharpe:  1.055065747616035
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.7664730272
# Sharpe:  1.0550695716455076
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826747.9601163857
# Sharpe:  1.0550671343210434
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 129       |
# |    time_elapsed    | 93        |
# |    total_timesteps | 12180     |
# | train/             |           |
# |    actor_loss      | -4.76e+07 |
# |    critic_loss     | 2.95e+12  |
# |    ent_coef        | 4.45      |
# |    ent_coef_loss   | -318      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 12079     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1826752.1829826962
# Sharpe:  1.055070884397684
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826766.6180483042
# Sharpe:  1.0550832287864225
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.9875382325
# Sharpe:  1.0550697702231409
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826752.7639084803
# Sharpe:  1.055071490697837
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 132       |
# |    time_elapsed    | 122       |
# |    total_timesteps | 16240     |
# | train/             |           |
# |    actor_loss      | -6.29e+07 |
# |    critic_loss     | 4.9e+12   |
# |    ent_coef        | 15        |
# |    ent_coef_loss   | -570      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 16139     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.5944467036
# Sharpe:  1.055069417015563
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 135       |
# |    time_elapsed    | 149       |
# |    total_timesteps | 20300     |
# | train/             |           |
# |    actor_loss      | -7.48e+07 |
# |    critic_loss     | 6.19e+12  |
# |    ent_coef        | 48.9      |
# |    ent_coef_loss   | -730      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 20199     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 137       |
# |    time_elapsed    | 177       |
# |    total_timesteps | 24360     |
# | train/             |           |
# |    actor_loss      | -8.37e+07 |
# |    critic_loss     | 5.76e+13  |
# |    ent_coef        | 165       |
# |    ent_coef_loss   | -960      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 24259     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.643904215
# Sharpe:  1.0550694611948854
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 137       |
# |    time_elapsed    | 206       |
# |    total_timesteps | 28420     |
# | train/             |           |
# |    actor_loss      | -9.13e+07 |
# |    critic_loss     | 7.53e+12  |
# |    ent_coef        | 558       |
# |    ent_coef_loss   | -1.19e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 28319     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 136       |
# |    time_elapsed    | 237       |
# |    total_timesteps | 32480     |
# | train/             |           |
# |    actor_loss      | -9.32e+07 |
# |    critic_loss     | 7.83e+12  |
# |    ent_coef        | 1.88e+03  |
# |    ent_coef_loss   | -1.42e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 32379     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826733.32030884
# Sharpe:  1.055053650233762
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.6439484903
# Sharpe:  1.0550694612381093
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 135       |
# |    time_elapsed    | 270       |
# |    total_timesteps | 36540     |
# | train/             |           |
# |    actor_loss      | -8.23e+07 |
# |    critic_loss     | 1.18e+13  |
# |    ent_coef        | 6.37e+03  |
# |    ent_coef_loss   | -1.65e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 36439     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.647001289
# Sharpe:  1.0550694640453566
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1826750.64433215
# Sharpe:  1.055069461588334
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1828224.0325346845
# Sharpe:  1.0562515984876868
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1831793.9838348604
# Sharpe:  1.0589720112684113
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 128       |
# |    time_elapsed    | 315       |
# |    total_timesteps | 40600     |
# | train/             |           |
# |    actor_loss      | -4.35e+07 |
# |    critic_loss     | 1.8e+13   |
# |    ent_coef        | 2.15e+04  |
# |    ent_coef_loss   | -1.72e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 40499     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1806098.9264215317
# Sharpe:  1.0349371714909772
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1841989.7042315025
# Sharpe:  1.0678496415402243
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1845259.965352191
# Sharpe:  1.0729127714054185
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1833708.0212864878
# Sharpe:  1.0617331838558093
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 128       |
# |    time_elapsed    | 348       |
# |    total_timesteps | 44660     |
# | train/             |           |
# |    actor_loss      | -2.99e+07 |
# |    critic_loss     | 9.35e+11  |
# |    ent_coef        | 2.99e+04  |
# |    ent_coef_loss   | -54.3     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 44559     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1800487.3030627985
# Sharpe:  1.033271890279943
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1843134.671500608
# Sharpe:  1.0706787453681184
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1825634.515804416
# Sharpe:  1.054946423963219
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1818578.6738794516
# Sharpe:  1.050087217568175
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 127       |
# |    time_elapsed    | 380       |
# |    total_timesteps | 48720     |
# | train/             |           |
# |    actor_loss      | -2.55e+07 |
# |    critic_loss     | 5.82e+11  |
# |    ent_coef        | 3.39e+04  |
# |    ent_coef_loss   | 2.18      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 48619     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1792431.920819976
# Sharpe:  1.0257356160720361
# =================================

# %% [markdown]
# #### 8.4.5 Model 5: TD3 : Twin Delayed Deep Deterministic Policy Gradien

# %%
agent = DRLAgents(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=30000)
# Out:
# Logging to tensorboard_log/td3/td3_5
# =================================
# begin_total_asset:1000000
# end_total_asset:1834581.0840704073
# Sharpe:  1.0406735944713668
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 122       |
# |    time_elapsed    | 33        |
# |    total_timesteps | 4060      |
# | train/             |           |
# |    actor_loss      | -1.05e+07 |
# |    critic_loss     | 4.75e+11  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 3959      |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 138       |
# |    time_elapsed    | 58        |
# |    total_timesteps | 8120      |
# | train/             |           |
# |    actor_loss      | -2.05e+07 |
# |    critic_loss     | 8.31e+11  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8019      |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 149       |
# |    time_elapsed    | 81        |
# |    total_timesteps | 12180     |
# | train/             |           |
# |    actor_loss      | -2.92e+07 |
# |    critic_loss     | 1.69e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12079     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 155       |
# |    time_elapsed    | 104       |
# |    total_timesteps | 16240     |
# | train/             |           |
# |    actor_loss      | -3.56e+07 |
# |    critic_loss     | 2.1e+12   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16139     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 160       |
# |    time_elapsed    | 126       |
# |    total_timesteps | 20300     |
# | train/             |           |
# |    actor_loss      | -4.15e+07 |
# |    critic_loss     | 2.44e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20199     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 162       |
# |    time_elapsed    | 149       |
# |    total_timesteps | 24360     |
# | train/             |           |
# |    actor_loss      | -4.48e+07 |
# |    critic_loss     | 2.93e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24259     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 163       |
# |    time_elapsed    | 173       |
# |    total_timesteps | 28420     |
# | train/             |           |
# |    actor_loss      | -4.91e+07 |
# |    critic_loss     | 3.39e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 28319     |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================

# %% [markdown]
# ### 8.5 Fittng Model on Training Data

# %%
# A2C Train Model
e_trade_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

a2c_train_daily_return, a2c_train_weights = DRLAgents.DRL_prediction(model=trained_a2c,
                        test_data = train_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# =================================
# begin_total_asset:1000000
# end_total_asset:1790541.9756475668
# Sharpe:  1.0206933131400584
# =================================

# %%
# PPO Train Model
e_trade_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ppo_train_daily_return, ppo_train_weights = DRLAgents.DRL_prediction(model=trained_ppo,
                        test_data = train_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# =================================
# begin_total_asset:1000000
# end_total_asset:2055045.5600348732
# Sharpe:  1.2531702186291702
# =================================

# %%
# DDPG Train Model
e_trade_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ddpg_train_daily_return, ddpg_train_weights = DRLAgents.DRL_prediction(model=trained_ddpg,
                        test_data = train_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# =================================
# begin_total_asset:1000000
# end_total_asset:1874216.9866449942
# Sharpe:  1.1163149272650246
# =================================

# %%
# SAC Train Model
e_trade_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

sac_train_daily_return, sac_train_weights = DRLAgents.DRL_prediction(model=trained_sac,
                        test_data = train_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# =================================
# begin_total_asset:1000000
# end_total_asset:1846167.3147196728
# Sharpe:  1.0751296092512685
# =================================

# %%
# TD3 Train Model
e_trade_gym = StockPortfolioEnv(df = train_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

td3_train_daily_return, td3_train_weights = DRLAgents.DRL_prediction(model=trained_td3,
                        test_data = train_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# =================================
# begin_total_asset:1000000
# end_total_asset:1868097.3487184967
# Sharpe:  1.0684380898678556
# =================================

# %%
# Store the Training Models
# %store a2c_train_daily_return
# %store ppo_train_daily_return
# %store ddpg_train_daily_return
# %store sac_train_daily_return
# %store td3_train_daily_return
# Out:
# Stored 'a2c_train_daily_return' (DataFrame)
# Stored 'ppo_train_daily_return' (DataFrame)
# Stored 'ddpg_train_daily_return' (DataFrame)
# Stored 'sac_train_daily_return' (DataFrame)
# Stored 'td3_train_daily_return' (DataFrame)

# %% [markdown]
# ### 8.6 Trading
# Assume that we have Rs1,000,000 initial capital at 2024-01-01. We use the DDPG model to trade NIFTY50 stocks

# %%
test_df.tail(5)
# Out:
#            date          tic        close         high          low  \
# 251  2024-02-26  RELIANCE.NS  2989.050049  2965.000000  2974.649902
# 251  2024-02-26   SBILIFE.NS  1553.400024  1525.099976  1549.150024
# 251  2024-02-26       TCS.NS  4050.000000  3982.750000  4001.050049
# 251  2024-02-26     TITAN.NS  3690.000000  3610.850098  3622.500000
# 251  2024-02-26     WIPRO.NS   536.500000   526.049988   532.900024
#
#             open   volume                                           cov_list  \
# 251  2987.100098  3756553  [[9.755062055703997e-05, 4.4546950611781485e-0...
# 251  1531.150024  1283074  [[9.755062055703997e-05, 4.4546950611781485e-0...
# 251  4036.000000  1379284  [[9.755062055703997e-05, 4.4546950611781485e-0...
# 251  3690.000000   546842  [[9.755062055703997e-05, 4.4546950611781485e-0...
# 251   536.250000  4410318  [[9.755062055703997e-05, 4.4546950611781485e-0...
#
#           f01       f02  f03       f04
# 251  0.510949  0.005566  0.0  3.781142
# 251  0.510949  0.005566  0.0  3.781142
# 251  0.510949  0.005566  0.0  3.781142
# 251  0.510949  0.005566  0.0  3.781142
# 251  0.510949  0.005566  0.0  3.781142

# %%
# A2C Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

a2c_test_daily_return, a2c_test_weights = DRLAgents.DRL_prediction(model=trained_a2c,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:1296811.6370321312
# Sharpe:  3.1430460632422927
# =================================
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %%
a2c_test_daily_return.head()
# Out:
#          date  daily_return
# 0  2023-02-16      0.000000
# 1  2023-02-17     -0.005276
# 2  2023-02-20     -0.001997
# 3  2023-02-21     -0.003438
# 4  2023-02-22     -0.010396

# %%
a2c_test_weights.to_csv('a2c_test_weights.csv')

# %%
a2c_test_weights.head()
# Out:
#             ASIANPAINT.NS  BAJAJ-AUTO.NS  GRASIM.NS  HCLTECH.NS  HDFCBANK.NS  \
# date
# 2023-02-16       0.050000       0.050000   0.050000    0.050000     0.050000
# 2023-02-17       0.078287       0.078287   0.028800    0.028800     0.078287
# 2023-02-20       0.055541       0.053976   0.029339    0.040607     0.079752
# 2023-02-21       0.095044       0.073877   0.034965    0.034965     0.095044
# 2023-02-22       0.087752       0.087752   0.032282    0.032282     0.087752
#
#             HDFCLIFE.NS  HINDUNILVR.NS  ICICIBANK.NS    ITC.NS  KOTAKBANK.NS  \
# date
# 2023-02-16     0.050000       0.050000      0.050000  0.050000      0.050000
# 2023-02-17     0.078287       0.062078      0.078287  0.063451      0.029875
# 2023-02-20     0.029339       0.069721      0.037440  0.029339      0.079036
# 2023-02-21     0.035297       0.056106      0.095044  0.034965      0.034965
# 2023-02-22     0.041471       0.032282      0.087752  0.032282      0.032282
#
#                LT.NS  MARUTI.NS  NESTLEIND.NS   NTPC.NS  POWERGRID.NS  \
# date
# 2023-02-16  0.050000   0.050000      0.050000  0.050000      0.050000
# 2023-02-17  0.028800   0.028800      0.028800  0.028800      0.028800
# 2023-02-20  0.079752   0.029339      0.029339  0.029339      0.030206
# 2023-02-21  0.034965   0.034965      0.034965  0.034965      0.034965
# 2023-02-22  0.032282   0.032282      0.032282  0.032282      0.044105
#
#             RELIANCE.NS  SBILIFE.NS    TCS.NS  TITAN.NS  WIPRO.NS
# date
# 2023-02-16     0.050000    0.050000  0.050000  0.050000  0.050000
# 2023-02-17     0.028800    0.030733  0.078287  0.042089  0.071648
# 2023-02-20     0.079752    0.029339  0.079752  0.079752  0.029339
# 2023-02-21     0.034965    0.034965  0.095044  0.034965  0.034965
# 2023-02-22     0.043077    0.032282  0.077482  0.087752  0.032282

# %%
# PPO Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ppo_test_daily_return, ppo_test_weights = DRLAgents.DRL_prediction(model=trained_ppo,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# =================================
# begin_total_asset:1000000
# end_total_asset:1291875.697714956
# Sharpe:  3.179998740437339
# =================================

# %%
ppo_test_weights.to_csv('ppo_test_weights')

# %%
# DDPG Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

ddpg_test_daily_return, ddpg_test_weights = DRLAgents.DRL_prediction(model=trained_ddpg,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# =================================
# begin_total_asset:1000000
# end_total_asset:1285002.5452271781
# Sharpe:  3.1333540864650433
# =================================

# %%
ddpg_test_weights.to_csv('ddpg_test_weights')

# %%
# SAC Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

sac_test_daily_return, sac_test_weights = DRLAgents.DRL_prediction(model=trained_sac,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# =================================
# begin_total_asset:1000000
# end_total_asset:1334937.5633620594
# Sharpe:  3.4159674591370908
# =================================

# %%
sac_test_weights.to_csv('sac_test_weights')

# %%
# TD3 Test Model
e_trade_gym = StockPortfolioEnv(df = test_df, **env_kwargs)
env_trade, obs_trade = e_trade_gym.get_sb_env()

td3_test_daily_return, td3_test_weights = DRLAgents.DRL_prediction(model=trained_sac,
                        test_data = test_df,
                        test_env = env_trade,
                        test_obs = obs_trade)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# =================================
# begin_total_asset:1000000
# end_total_asset:1336283.8886596966
# Sharpe:  3.421345262391123
# =================================

# %%
td3_test_weights.to_csv('td3_test_weights')

# %% [markdown]
# ### 8.7 Save the Portfolios

# %%
a2c_test_portfolio = a2c_test_daily_return.copy()
a2c_test_returns = a2c_test_daily_return.copy()

ppo_test_portfolio = ppo_test_daily_return.copy()
ppo_test_returns = ppo_test_daily_return.copy()

ddpg_test_portfolio = ddpg_test_daily_return.copy()
ddpg_test_returns = ddpg_test_daily_return.copy()

sac_test_portfolio = sac_test_daily_return.copy()
sac_test_returns = sac_test_daily_return.copy()

td3_test_portfolio = td3_test_daily_return.copy()
td3_test_returns = td3_test_daily_return.copy()

# %%
# %store a2c_test_portfolio
# %store a2c_test_returns 

# %store ppo_test_portfolio
# %store ppo_test_returns 

# %store ddpg_test_portfolio
# %store ddpg_test_returns 

# %store sac_test_portfolio
# %store sac_test_returns

# %store td3_test_portfolio
# %store td3_test_returns
# Out:
# Stored 'a2c_test_portfolio' (DataFrame)
# Stored 'a2c_test_returns' (DataFrame)
# Stored 'ppo_test_portfolio' (DataFrame)
# Stored 'ppo_test_returns' (DataFrame)
# Stored 'ddpg_test_portfolio' (DataFrame)
# Stored 'ddpg_test_returns' (DataFrame)
# Stored 'sac_test_portfolio' (DataFrame)
# Stored 'sac_test_returns' (DataFrame)
# Stored 'td3_test_portfolio' (DataFrame)
# Stored 'td3_test_returns' (DataFrame)
