# %% [markdown]
# # Portfolio Optimization using Deep Reinforcement Learning
# ----

# %% [markdown]
# ## 3.0 Stock Selection
# ---
# Auto Encoders are employed to select the less volatile stocks by choosing stocks with less reconstruction error. These are the stocks that are included in the portfolio

# %% [markdown]
# ### 3.1 Import Relevant Libraries

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import keras

# %%
from numpy import array
from keras.models import Model
from keras.layers import Input
from keras.layers import LSTM
from keras.layers import Dense, Activation
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.utils import plot_model
from keras import regularizers, optimizers

from sklearn import preprocessing

# %% [markdown]
# ### 3.2 Load the Data

# %%
# Load the close prices dataset
prices_data = pd.read_csv('./datasets/close_prices.csv')

# %%
df = prices_data.copy()

# %%
df = df.reset_index(drop=True).set_index(['date'])

# %%
df.head()
# Out:
#             BRITANNIA.NS  AXISBANK.NS  TATASTEEL.NS  HEROMOTOCO.NS  \
# date
# 2018-01-01   2387.000000   569.799988     70.064255    3810.000000
# 2018-01-02   2371.125000   568.599976     69.668869    3784.350098
# 2018-01-03   2354.975098   565.450012     70.264328    3764.399902
# 2018-01-04   2344.449951   565.000000     72.736679    3759.949951
# 2018-01-05   2339.750000   566.000000     74.018112    3758.699951
#
#             TATACONSUM.NS  HDFCLIFE.NS    GRASIM.NS  JSWSTEEL.NS  \
# date
# 2018-01-01     317.799988   399.799988  1165.166992   271.700012
# 2018-01-02     314.950012   398.000000  1149.529175   268.000000
# 2018-01-03     315.149994   398.299988  1144.798096   272.250000
# 2018-01-04     313.500000   401.950012  1170.844482   281.899994
# 2018-01-05     315.850006   412.000000  1214.172241   289.899994
#
#             BAJAJ-AUTO.NS     NTPC.NS  ...  BHARTIARTL.NS  NESTLEIND.NS  \
# date                                   ...
# 2018-01-01    3345.050049  147.791672  ...     484.966522    790.159973
# 2018-01-02    3348.000000  149.375000  ...     480.279999    792.304993
# 2018-01-03    3310.199951  150.250000  ...     473.610687    793.500000
# 2018-01-04    3274.250000  148.250000  ...     475.142822    790.219971
# 2018-01-05    3294.000000  148.541672  ...     488.932068    788.400024
#
#             APOLLOHOSP.NS  BAJFINANCE.NS     INFY.NS     ONGC.NS  \
# date
# 2018-01-01    1216.000000    1760.000000  522.250000  195.699997
# 2018-01-02    1212.000000    1739.699951  521.000000  197.500000
# 2018-01-03    1203.949951    1738.349976  515.799988  197.399994
# 2018-01-04    1188.449951    1758.250000  510.500000  200.000000
# 2018-01-05    1199.000000    1821.000000  513.200012  200.949997
#
#             SUNPHARMA.NS  POWERGRID.NS  INDUSINDBK.NS  BAJAJFINSV.NS
# date
# 2018-01-01    585.400024    113.484406    1655.949951     530.875000
# 2018-01-02    582.000000    113.512527    1647.000000     522.900024
# 2018-01-03    578.950012    113.878151    1650.000000     517.979980
# 2018-01-04    583.950012    114.103149    1652.500000     513.500000
# 2018-01-05    587.349976    113.653152    1703.000000     514.494995
#
# [5 rows x 50 columns]

# %% [markdown]
# ### 3.3 Define Functions

# %%
def defineAutoencoder(num_stock, encoding_dim = 5, verbose=0):
    
    """
    Function for fitting an Autoencoder
    """

    # connect all layers
    input = Input(shape=(num_stock,))

    encoded = Dense(encoding_dim, kernel_regularizer=regularizers.l2(0.00001),name ='Encoder_Input')(input)

    decoded = Dense(num_stock, kernel_regularizer=regularizers.l2(0.00001), name ='Decoder_Input')(encoded)
    decoded = Activation("linear", name='Decoder_Activation_function')(decoded)

    # construct and compile AE model
    autoencoder = Model(inputs=input, outputs=decoded)
    adam = optimizers.Adam(learning_rate=0.0005)
    autoencoder.compile(optimizer=adam, loss='mean_squared_error')
    if verbose!= 0:
        autoencoder.summary()

    return autoencoder

# %%
def getReconstructionErrorsDF(df_pct_change, reconstructed_data):
    
    """
    Function for calculating the reconstruction Errors
    """
    array = []
    stocks_ranked = []
    num_columns = reconstructed_data.shape[1]
    for i in range(0, num_columns):
        diff = np.linalg.norm((df_pct_change.iloc[:, i] - reconstructed_data[:, i]))  # 2 norm difference
        array.append(float(diff))

    ranking = np.array(array).argsort()
    r = 1
    for stock_index in ranking:
        stocks_ranked.append([ r
                              ,stock_index
                              ,df_pct_change.iloc[:, stock_index].name
                              ,array[stock_index]
                              ])
        r = r + 1

    columns = ['ranking','stock_index', 'stock_name' ,'recreation_error']
    df = pd.DataFrame(stocks_ranked, columns=columns)
    df = df.set_index('stock_name')
    return df

# %% [markdown]
# ### 3.4 Get the Percentage Change of the Close Prices

# %%
col_names = df.columns.to_list()

# %%
print(col_names)
# Out:
# ['BRITANNIA.NS', 'AXISBANK.NS', 'TATASTEEL.NS', 'HEROMOTOCO.NS', 'TATACONSUM.NS', 'HDFCLIFE.NS', 'GRASIM.NS', 'JSWSTEEL.NS', 'BAJAJ-AUTO.NS', 'NTPC.NS', 'SBIN.NS', 'M&M.NS', 'HCLTECH.NS', 'SHRIRAMFIN.NS', 'ADANIENT.NS', 'DRREDDY.NS', 'ITC.NS', 'LTIM.NS', 'ADANIPORTS.NS', 'COALINDIA.NS', 'TITAN.NS', 'EICHERMOT.NS', 'ICICIBANK.NS', 'BPCL.NS', 'SBILIFE.NS', 'HDFCBANK.NS', 'LT.NS', 'HINDALCO.NS', 'CIPLA.NS', 'DIVISLAB.NS', 'ASIANPAINT.NS', 'TATAMOTORS.NS', 'TCS.NS', 'KOTAKBANK.NS', 'MARUTI.NS', 'TECHM.NS', 'HINDUNILVR.NS', 'RELIANCE.NS', 'WIPRO.NS', 'ULTRACEMCO.NS', 'BHARTIARTL.NS', 'NESTLEIND.NS', 'APOLLOHOSP.NS', 'BAJFINANCE.NS', 'INFY.NS', 'ONGC.NS', 'SUNPHARMA.NS', 'POWERGRID.NS', 'INDUSINDBK.NS', 'BAJAJFINSV.NS']

# %%
df_pct_change = df.pct_change(1).astype(float)
df_pct_change = df_pct_change.replace([np.inf, -np.inf], np.nan)
df_pct_change = df_pct_change.fillna(method='bfill')

# the percentage change function will make the first two rows equal to nan
df_pct_change = df_pct_change.tail(len(df_pct_change) - 2)
# Out:
# /var/folders/3z/6b2hp23s5sg2j9x4jt4hyh_80000gn/T/ipykernel_165/2395198504.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df_pct_change = df_pct_change.fillna(method='bfill')

# %%
if df_pct_change.isnull().values.any():
    print("Warning: NaN values detected in df_pct_change. Please handle them before calculating reconstruction errors.")

# %%
df_pct_change.shape
# Out:
# (1519, 50)

# %%
# remove columns where there is no change over a longer time period
df_pct_change = df_pct_change[df_pct_change.columns[((df_pct_change == 0).mean() <= 0.05)]]

# %%
df_pct_change.head()
# Out:
#             BRITANNIA.NS  AXISBANK.NS  TATASTEEL.NS  HEROMOTOCO.NS  \
# date
# 2018-01-03     -0.006811    -0.005540      0.008547      -0.005272
# 2018-01-04     -0.004469    -0.000796      0.035186      -0.001182
# 2018-01-05     -0.002005     0.001770      0.017617      -0.000332
# 2018-01-08      0.006731     0.003534      0.001223       0.008859
# 2018-01-09      0.000499     0.008803      0.003857       0.003376
#
#             TATACONSUM.NS  HDFCLIFE.NS  GRASIM.NS  JSWSTEEL.NS  BAJAJ-AUTO.NS  \
# date
# 2018-01-03       0.000635     0.000754  -0.004116     0.015858      -0.011290
# 2018-01-04      -0.005236     0.009164   0.022752     0.035445      -0.010860
# 2018-01-05       0.007496     0.025003   0.037006     0.028379       0.006032
# 2018-01-08       0.010606     0.039563  -0.002871    -0.001380       0.000820
# 2018-01-09       0.001410     0.045179   0.023365     0.000000      -0.003701
#
#              NTPC.NS  ...  BHARTIARTL.NS  NESTLEIND.NS  APOLLOHOSP.NS  \
# date                  ...
# 2018-01-03  0.005858  ...      -0.013886      0.001508      -0.006642
# 2018-01-04 -0.013311  ...       0.003235     -0.004134      -0.012874
# 2018-01-05  0.001967  ...       0.029021     -0.002303       0.008877
# 2018-01-08  0.001402  ...      -0.015392      0.010724       0.008340
# 2018-01-09 -0.000560  ...      -0.024525      0.000038      -0.015095
#
#             BAJFINANCE.NS   INFY.NS   ONGC.NS  SUNPHARMA.NS  POWERGRID.NS  \
# date
# 2018-01-03      -0.000776 -0.009981 -0.000506     -0.005241      0.003221
# 2018-01-04       0.011448 -0.010275  0.013171      0.008636      0.001976
# 2018-01-05       0.035689  0.005289  0.004750      0.005822     -0.003944
# 2018-01-08       0.012081  0.012276 -0.005225      0.029369      0.005939
# 2018-01-09       0.000000  0.005679 -0.004502     -0.010916     -0.009102
#
#             INDUSINDBK.NS  BAJAJFINSV.NS
# date
# 2018-01-03       0.001821      -0.009409
# 2018-01-04       0.001515      -0.008649
# 2018-01-05       0.030560       0.001938
# 2018-01-08       0.012331       0.021001
# 2018-01-09       0.003451      -0.002018
#
# [5 rows x 50 columns]

# %% [markdown]
# ### 3.5 Construct the Autoencoder

# %%
# define the input parameters
hidden_layers = 5
batch_size = 500
epochs = 500
stock_selection_number = 20
num_stock = df_pct_change.shape[1]
verbose = 1

# %%
print('-' * 20 + 'Step 1 : Returns vs. recreation error (recreation_error)')
print('-' * 25 + 'Transform dataset with MinMax Scaler')
# Out:
# --------------------Step 1 : Returns vs. recreation error (recreation_error)
# -------------------------Transform dataset with MinMax Scaler

# %%
# Normalize the data
df_scaler = preprocessing.MinMaxScaler()
df_pct_change_normalised = df_scaler.fit_transform(df_pct_change)

# %%
# define autoencoder
print('-' * 25 + 'Define autoencoder model')
num_stock = len(df_pct_change.columns)
autoencoder = defineAutoencoder(num_stock=num_stock, encoding_dim=hidden_layers, verbose=verbose)
#plot_model(autoencoder, to_file='img/model_autoencoder_1.png', show_shapes=True,
#           show_layer_names=True)
# Out:
# -------------------------Define autoencoder model
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Encoder_Input (Dense)           │ (None, 5)              │           255 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Decoder_Input (Dense)           │ (None, 50)             │           300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Decoder_Activation_function     │ (None, 50)             │             0 │
# │ (Activation)                    │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 555 (2.17 KB)
#  Trainable params: 555 (2.17 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# train autoencoder
print('-' * 25 + 'Train autoencoder model')
autoencoder.fit(df_pct_change_normalised, df_pct_change_normalised, shuffle=False, epochs=epochs,
                batch_size=batch_size,
                verbose=verbose)
# Out:
# -------------------------Train autoencoder model
# Epoch 1/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3100
# Epoch 2/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 726us/step - loss: 0.2920
# Epoch 3/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - loss: 0.2756
# Epoch 4/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 0.2606
# Epoch 5/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step - loss: 0.2470
# Epoch 6/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - loss: 0.2347
# Epoch 7/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2235
# Epoch 8/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step - loss: 0.2132
# Epoch 9/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 805us/step - loss: 0.2038
# Epoch 10/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 639us/step - loss: 0.1950
# Epoch 11/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 686us/step - loss: 0.1868
# Epoch 12/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - loss: 0.1791
# Epoch 13/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 567us/step - loss: 0.1720
# Epoch 14/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1652
# Epoch 15/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step - loss: 0.1589
# Epoch 16/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 813us/step - loss: 0.1530
# Epoch 17/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 656us/step - loss: 0.1474
# Epoch 18/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1421
# Epoch 19/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1370
# Epoch 20/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - loss: 0.1322
# Epoch 21/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step - loss: 0.1276
# Epoch 22/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 0.1231
# Epoch 23/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step - loss: 0.1189
# Epoch 24/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.1148
# Epoch 25/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 0.1108
# Epoch 26/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - loss: 0.1070
# Epoch 27/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 849us/step - loss: 0.1034
# Epoch 28/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step - loss: 0.0998
# Epoch 29/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - loss: 0.0964
# Epoch 30/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.0930
# Epoch 31/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 555us/step - loss: 0.0898
# Epoch 32/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 614us/step - loss: 0.0867
# Epoch 33/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - loss: 0.0836
# Epoch 34/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - loss: 0.0807
# Epoch 35/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - loss: 0.0779
# Epoch 36/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - loss: 0.0751
# Epoch 37/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - loss: 0.0724
# Epoch 38/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 690us/step - loss: 0.0699
# Epoch 39/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step - loss: 0.0673
# Epoch 40/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step - loss: 0.0649
# Epoch 41/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 652us/step - loss: 0.0626
# Epoch 42/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 653us/step - loss: 0.0603
# Epoch 43/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - loss: 0.0581
# Epoch 44/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.0560
# Epoch 45/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - loss: 0.0539
# Epoch 46/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 603us/step - loss: 0.0519
# Epoch 47/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - loss: 0.0500
# Epoch 48/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - loss: 0.0482
# Epoch 49/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - loss: 0.0464
# Epoch 50/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - loss: 0.0446
# Epoch 51/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.0430
# Epoch 52/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 0.0414
# Epoch 53/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.0398
# Epoch 54/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - loss: 0.0383
# Epoch 55/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - loss: 0.0369
# Epoch 56/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - loss: 0.0355
# Epoch 57/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 723us/step - loss: 0.0341
# Epoch 58/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 637us/step - loss: 0.0329
# Epoch 59/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - loss: 0.0316
# Epoch 60/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.0304
# Epoch 61/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - loss: 0.0293
# Epoch 62/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 664us/step - loss: 0.0282
# Epoch 63/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.0271
# Epoch 64/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 900us/step - loss: 0.0261
# Epoch 65/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - loss: 0.0252
# Epoch 66/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 629us/step - loss: 0.0243
# Epoch 67/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - loss: 0.0234
# Epoch 68/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - loss: 0.0225
# Epoch 69/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - loss: 0.0217
# Epoch 70/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step - loss: 0.0209
# Epoch 71/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step - loss: 0.0202
# Epoch 72/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step - loss: 0.0195
# Epoch 73/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 0.0188
# Epoch 74/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - loss: 0.0182
# Epoch 75/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step - loss: 0.0175
# Epoch 76/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - loss: 0.0169
# Epoch 77/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 666us/step - loss: 0.0164
# Epoch 78/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - loss: 0.0158
# Epoch 79/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - loss: 0.0153
# Epoch 80/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0148
# Epoch 81/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0144
# Epoch 82/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - loss: 0.0139
# Epoch 83/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - loss: 0.0135
# Epoch 84/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step - loss: 0.0131
# Epoch 85/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - loss: 0.0127
# Epoch 86/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - loss: 0.0123
# Epoch 87/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0120
# Epoch 88/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0116
# Epoch 89/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0113
# Epoch 90/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step - loss: 0.0110
# Epoch 91/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.0107
# Epoch 92/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 0.0104
# Epoch 93/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 586us/step - loss: 0.0102
# Epoch 94/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 580us/step - loss: 0.0099
# Epoch 95/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step - loss: 0.0097
# Epoch 96/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - loss: 0.0094
# Epoch 97/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.0092
# Epoch 98/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - loss: 0.0090
# Epoch 99/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 659us/step - loss: 0.0088
# Epoch 100/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - loss: 0.0086
# Epoch 101/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - loss: 0.0084
# Epoch 102/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 634us/step - loss: 0.0083
# Epoch 103/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 0.0081
# Epoch 104/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 520us/step - loss: 0.0079
# Epoch 105/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 531us/step - loss: 0.0078
# Epoch 106/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - loss: 0.0077
# Epoch 107/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 526us/step - loss: 0.0075
# Epoch 108/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.0074
# Epoch 109/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - loss: 0.0073
# Epoch 110/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 644us/step - loss: 0.0072
# Epoch 111/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 557us/step - loss: 0.0070
# Epoch 112/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 564us/step - loss: 0.0069
# Epoch 113/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step - loss: 0.0068
# Epoch 114/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 648us/step - loss: 0.0068
# Epoch 115/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 587us/step - loss: 0.0067
# Epoch 116/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 599us/step - loss: 0.0066
# Epoch 117/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - loss: 0.0065
# Epoch 118/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.0064
# Epoch 119/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - loss: 0.0063
# Epoch 120/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - loss: 0.0063
# Epoch 121/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - loss: 0.0062
# Epoch 122/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.0062
# Epoch 123/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 551us/step - loss: 0.0061
# Epoch 124/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - loss: 0.0060
# Epoch 125/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.0060
# Epoch 126/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.0059
# Epoch 127/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - loss: 0.0059
# Epoch 128/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.0058
# Epoch 129/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 0.0058
# Epoch 130/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - loss: 0.0058
# Epoch 131/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.0057
# Epoch 132/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057
# Epoch 133/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057
# Epoch 134/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.0056
# Epoch 135/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 0.0056
# Epoch 136/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.0056
# Epoch 137/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - loss: 0.0055
# Epoch 138/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - loss: 0.0055
# Epoch 139/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 577us/step - loss: 0.0055
# Epoch 140/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 0.0055
# Epoch 141/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 568us/step - loss: 0.0054
# Epoch 142/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.0054
# Epoch 143/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.0054
# Epoch 144/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.0054
# Epoch 145/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.0054
# Epoch 146/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - loss: 0.0054
# Epoch 147/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 0.0053
# Epoch 148/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 0.0053
# Epoch 149/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - loss: 0.0053
# Epoch 150/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 0.0053
# Epoch 151/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.0053
# Epoch 152/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 562us/step - loss: 0.0053
# Epoch 153/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 609us/step - loss: 0.0053
# Epoch 154/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0053
# Epoch 155/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.0052
# Epoch 156/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 0.0052
# Epoch 157/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - loss: 0.0052
# Epoch 158/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.0052
# Epoch 159/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - loss: 0.0052
# Epoch 160/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 544us/step - loss: 0.0052
# Epoch 161/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 550us/step - loss: 0.0052
# Epoch 162/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - loss: 0.0052
# Epoch 163/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step - loss: 0.0052
# Epoch 164/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 0.0052
# Epoch 165/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 566us/step - loss: 0.0052
# Epoch 166/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - loss: 0.0052
# Epoch 167/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - loss: 0.0052
# Epoch 168/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 533us/step - loss: 0.0052
# Epoch 169/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 540us/step - loss: 0.0051
# Epoch 170/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.0051
# Epoch 171/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - loss: 0.0051
# Epoch 172/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 574us/step - loss: 0.0051
# Epoch 173/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.0051
# Epoch 174/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - loss: 0.0051
# Epoch 175/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0051
# Epoch 176/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.0051
# Epoch 177/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 560us/step - loss: 0.0051
# Epoch 178/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.0051
# Epoch 179/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - loss: 0.0051
# Epoch 180/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - loss: 0.0051
# Epoch 181/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - loss: 0.0051
# Epoch 182/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.0051
# Epoch 183/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 604us/step - loss: 0.0051
# Epoch 184/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.0051
# Epoch 185/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - loss: 0.0051
# Epoch 186/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - loss: 0.0051
# Epoch 187/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0051
# Epoch 188/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - loss: 0.0051
# Epoch 189/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 987us/step - loss: 0.0051
# Epoch 190/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step - loss: 0.0051
# Epoch 191/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.0051
# Epoch 192/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 559us/step - loss: 0.0051
# Epoch 193/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 622us/step - loss: 0.0051
# Epoch 194/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - loss: 0.0051
# Epoch 195/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - loss: 0.0051
# Epoch 196/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.0051
# Epoch 197/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 538us/step - loss: 0.0051
# Epoch 198/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - loss: 0.0051
# Epoch 199/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 535us/step - loss: 0.0051
# Epoch 200/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 602us/step - loss: 0.0050
# Epoch 201/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 601us/step - loss: 0.0050
# Epoch 202/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 606us/step - loss: 0.0050
# Epoch 203/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - loss: 0.0050
# Epoch 204/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.0050
# Epoch 205/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 636us/step - loss: 0.0050
# Epoch 206/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - loss: 0.0050
# Epoch 207/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 885us/step - loss: 0.0050
# Epoch 208/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - loss: 0.0050
# Epoch 209/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 651us/step - loss: 0.0050
# Epoch 210/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 692us/step - loss: 0.0050
# Epoch 211/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050
# Epoch 212/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step - loss: 0.0050
# Epoch 213/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - loss: 0.0050
# Epoch 214/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step - loss: 0.0050
# Epoch 215/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 620us/step - loss: 0.0050
# Epoch 216/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step - loss: 0.0050
# Epoch 217/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 643us/step - loss: 0.0050
# Epoch 218/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 607us/step - loss: 0.0050
# Epoch 219/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - loss: 0.0050
# Epoch 220/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.0050
# Epoch 221/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step - loss: 0.0050
# Epoch 222/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - loss: 0.0050
# Epoch 223/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.0050
# Epoch 224/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step - loss: 0.0050
# Epoch 225/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step - loss: 0.0050
# Epoch 226/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - loss: 0.0050
# Epoch 227/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 597us/step - loss: 0.0050
# Epoch 228/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - loss: 0.0050
# Epoch 229/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 585us/step - loss: 0.0050
# Epoch 230/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - loss: 0.0050
# Epoch 231/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - loss: 0.0050
# Epoch 232/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - loss: 0.0050
# Epoch 233/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - loss: 0.0050
# Epoch 234/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 569us/step - loss: 0.0050
# Epoch 235/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 645us/step - loss: 0.0050
# Epoch 236/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 492us/step - loss: 0.0050
# Epoch 237/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 0.0050
# Epoch 238/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.0050
# Epoch 239/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0050
# Epoch 240/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0050
# Epoch 241/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 539us/step - loss: 0.0050
# Epoch 242/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.0050
# Epoch 243/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 626us/step - loss: 0.0050
# Epoch 244/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.0050
# Epoch 245/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.0050
# Epoch 246/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 518us/step - loss: 0.0050
# Epoch 247/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 549us/step - loss: 0.0049
# Epoch 248/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 628us/step - loss: 0.0049
# Epoch 249/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 623us/step - loss: 0.0049
# Epoch 250/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 612us/step - loss: 0.0049
# Epoch 251/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 649us/step - loss: 0.0049
# Epoch 252/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 596us/step - loss: 0.0049
# Epoch 253/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 548us/step - loss: 0.0049
# Epoch 254/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 570us/step - loss: 0.0049
# Epoch 255/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 627us/step - loss: 0.0049
# Epoch 256/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 522us/step - loss: 0.0049
# Epoch 257/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.0049
# Epoch 258/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.0049
# Epoch 259/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 546us/step - loss: 0.0049
# Epoch 260/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 490us/step - loss: 0.0049
# Epoch 261/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.0049
# Epoch 262/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 0.0049
# Epoch 263/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.0049
# Epoch 264/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 513us/step - loss: 0.0049
# Epoch 265/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.0049
# Epoch 266/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 547us/step - loss: 0.0049
# Epoch 267/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.0049
# Epoch 268/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 466us/step - loss: 0.0049
# Epoch 269/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 503us/step - loss: 0.0049
# Epoch 270/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 0.0049
# Epoch 271/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.0049
# Epoch 272/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.0049
# Epoch 273/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.0049
# Epoch 274/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 0.0049
# Epoch 275/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 494us/step - loss: 0.0049
# Epoch 276/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0049
# Epoch 277/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - loss: 0.0049
# Epoch 278/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 561us/step - loss: 0.0049
# Epoch 279/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.0049
# Epoch 280/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.0049
# Epoch 281/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.0049
# Epoch 282/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.0049
# Epoch 283/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.0049
# Epoch 284/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 0.0049
# Epoch 285/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - loss: 0.0049
# Epoch 286/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step - loss: 0.0049
# Epoch 287/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.0049
# Epoch 288/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.0049
# Epoch 289/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 495us/step - loss: 0.0049
# Epoch 290/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.0049
# Epoch 291/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.0049
# Epoch 292/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.0049
# Epoch 293/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 510us/step - loss: 0.0049
# Epoch 294/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.0049
# Epoch 295/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 0.0049
# Epoch 296/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 571us/step - loss: 0.0049
# Epoch 297/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 615us/step - loss: 0.0049
# Epoch 298/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 545us/step - loss: 0.0049
# Epoch 299/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.0049
# Epoch 300/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 576us/step - loss: 0.0048
# Epoch 301/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 631us/step - loss: 0.0048
# Epoch 302/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - loss: 0.0048
# Epoch 303/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0048
# Epoch 304/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - loss: 0.0048
# Epoch 305/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - loss: 0.0048
# Epoch 306/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - loss: 0.0048
# Epoch 307/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 0.0048
# Epoch 308/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - loss: 0.0048
# Epoch 309/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step - loss: 0.0048
# Epoch 310/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 575us/step - loss: 0.0048
# Epoch 311/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.0048
# Epoch 312/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 554us/step - loss: 0.0048
# Epoch 313/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 600us/step - loss: 0.0048
# Epoch 314/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 563us/step - loss: 0.0048
# Epoch 315/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.0048
# Epoch 316/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 541us/step - loss: 0.0048
# Epoch 317/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - loss: 0.0048
# Epoch 318/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 591us/step - loss: 0.0048
# Epoch 319/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 509us/step - loss: 0.0048
# Epoch 320/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.0048
# Epoch 321/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 588us/step - loss: 0.0048
# Epoch 322/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 565us/step - loss: 0.0048
# Epoch 323/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 507us/step - loss: 0.0048
# Epoch 324/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.0048
# Epoch 325/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.0048
# Epoch 326/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 0.0048
# Epoch 327/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 573us/step - loss: 0.0048
# Epoch 328/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.0048
# Epoch 329/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.0048
# Epoch 330/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.0048
# Epoch 331/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.0048
# Epoch 332/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0048
# Epoch 333/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0048
# Epoch 334/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.0048
# Epoch 335/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.0048
# Epoch 336/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.0048
# Epoch 337/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 579us/step - loss: 0.0048
# Epoch 338/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 524us/step - loss: 0.0048
# Epoch 339/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.0048
# Epoch 340/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 610us/step - loss: 0.0048
# Epoch 341/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 552us/step - loss: 0.0048
# Epoch 342/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 528us/step - loss: 0.0048
# Epoch 343/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 527us/step - loss: 0.0048
# Epoch 344/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.0048
# Epoch 345/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.0048
# Epoch 346/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 519us/step - loss: 0.0048
# Epoch 347/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 473us/step - loss: 0.0048
# Epoch 348/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 454us/step - loss: 0.0048
# Epoch 349/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.0048
# Epoch 350/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 505us/step - loss: 0.0048
# Epoch 351/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.0048
# Epoch 352/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.0048
# Epoch 353/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0048
# Epoch 354/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.0048
# Epoch 355/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.0048
# Epoch 356/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0048
# Epoch 357/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 625us/step - loss: 0.0048
# Epoch 358/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 525us/step - loss: 0.0048
# Epoch 359/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.0047
# Epoch 360/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 493us/step - loss: 0.0047
# Epoch 361/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 0.0047
# Epoch 362/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 529us/step - loss: 0.0047
# Epoch 363/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 532us/step - loss: 0.0047
# Epoch 364/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 515us/step - loss: 0.0047
# Epoch 365/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.0047
# Epoch 366/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.0047
# Epoch 367/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - loss: 0.0047
# Epoch 368/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 446us/step - loss: 0.0047
# Epoch 369/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.0047
# Epoch 370/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 472us/step - loss: 0.0047
# Epoch 371/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.0047
# Epoch 372/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.0047
# Epoch 373/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.0047
# Epoch 374/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - loss: 0.0047
# Epoch 375/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0047
# Epoch 376/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.0047
# Epoch 377/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.0047
# Epoch 378/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0047
# Epoch 379/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.0047
# Epoch 380/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.0047
# Epoch 381/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.0047
# Epoch 382/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.0047
# Epoch 383/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.0047
# Epoch 384/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0047
# Epoch 385/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 681us/step - loss: 0.0047
# Epoch 386/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 497us/step - loss: 0.0047
# Epoch 387/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.0047
# Epoch 388/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.0047
# Epoch 389/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.0047
# Epoch 390/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.0047
# Epoch 391/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.0047
# Epoch 392/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.0047
# Epoch 393/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 444us/step - loss: 0.0047
# Epoch 394/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.0047
# Epoch 395/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 0.0047
# Epoch 396/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.0047
# Epoch 397/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 0.0047
# Epoch 398/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.0047
# Epoch 399/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 458us/step - loss: 0.0047
# Epoch 400/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 453us/step - loss: 0.0047
# Epoch 401/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 0.0047
# Epoch 402/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.0047
# Epoch 403/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.0047
# Epoch 404/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 432us/step - loss: 0.0047
# Epoch 405/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.0047
# Epoch 406/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047
# Epoch 407/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0047
# Epoch 408/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.0047
# Epoch 409/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.0047
# Epoch 410/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 468us/step - loss: 0.0047
# Epoch 411/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 460us/step - loss: 0.0047
# Epoch 412/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.0047
# Epoch 413/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.0047
# Epoch 414/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.0047
# Epoch 415/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.0047
# Epoch 416/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 511us/step - loss: 0.0047
# Epoch 417/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 441us/step - loss: 0.0047
# Epoch 418/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.0047
# Epoch 419/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 439us/step - loss: 0.0047
# Epoch 420/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.0047
# Epoch 421/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 455us/step - loss: 0.0047
# Epoch 422/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.0047
# Epoch 423/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.0047
# Epoch 424/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 456us/step - loss: 0.0046
# Epoch 425/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.0046
# Epoch 426/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - loss: 0.0046
# Epoch 427/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 431us/step - loss: 0.0046
# Epoch 428/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.0046
# Epoch 429/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 452us/step - loss: 0.0046
# Epoch 430/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.0046
# Epoch 431/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 448us/step - loss: 0.0046
# Epoch 432/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 463us/step - loss: 0.0046
# Epoch 433/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - loss: 0.0046
# Epoch 434/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0046
# Epoch 435/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 584us/step - loss: 0.0046
# Epoch 436/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 514us/step - loss: 0.0046
# Epoch 437/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 469us/step - loss: 0.0046
# Epoch 438/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.0046
# Epoch 439/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.0046
# Epoch 440/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.0046
# Epoch 441/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 462us/step - loss: 0.0046
# Epoch 442/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 447us/step - loss: 0.0046
# Epoch 443/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.0046
# Epoch 444/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 465us/step - loss: 0.0046
# Epoch 445/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - loss: 0.0046
# Epoch 446/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - loss: 0.0046
# Epoch 447/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.0046
# Epoch 448/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 415us/step - loss: 0.0046
# Epoch 449/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 487us/step - loss: 0.0046
# Epoch 450/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 445us/step - loss: 0.0046
# Epoch 451/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step - loss: 0.0046
# Epoch 452/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 428us/step - loss: 0.0046
# Epoch 453/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 477us/step - loss: 0.0046
# Epoch 454/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 0.0046
# Epoch 455/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 464us/step - loss: 0.0046
# Epoch 456/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0046
# Epoch 457/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 608us/step - loss: 0.0046
# Epoch 458/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 558us/step - loss: 0.0046
# Epoch 459/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.0046
# Epoch 460/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 474us/step - loss: 0.0046
# Epoch 461/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 506us/step - loss: 0.0046
# Epoch 462/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 499us/step - loss: 0.0046
# Epoch 463/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 500us/step - loss: 0.0046
# Epoch 464/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 581us/step - loss: 0.0046
# Epoch 465/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 590us/step - loss: 0.0046
# Epoch 466/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.0046
# Epoch 467/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step - loss: 0.0046
# Epoch 468/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 523us/step - loss: 0.0046
# Epoch 469/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 516us/step - loss: 0.0046
# Epoch 470/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 512us/step - loss: 0.0046
# Epoch 471/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 476us/step - loss: 0.0046
# Epoch 472/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 485us/step - loss: 0.0046
# Epoch 473/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 471us/step - loss: 0.0046
# Epoch 474/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 536us/step - loss: 0.0046
# Epoch 475/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0046
# Epoch 476/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 916us/step - loss: 0.0046
# Epoch 477/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 572us/step - loss: 0.0046
# Epoch 478/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.0046
# Epoch 479/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 443us/step - loss: 0.0046
# Epoch 480/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 496us/step - loss: 0.0046
# Epoch 481/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 489us/step - loss: 0.0046
# Epoch 482/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 475us/step - loss: 0.0046
# Epoch 483/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 480us/step - loss: 0.0046
# Epoch 484/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 498us/step - loss: 0.0046
# Epoch 485/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 459us/step - loss: 0.0046
# Epoch 486/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 461us/step - loss: 0.0046
# Epoch 487/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.0046
# Epoch 488/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 449us/step - loss: 0.0046
# Epoch 489/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 484us/step - loss: 0.0046
# Epoch 490/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step - loss: 0.0046
# Epoch 491/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 481us/step - loss: 0.0046
# Epoch 492/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 450us/step - loss: 0.0046
# Epoch 493/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 470us/step - loss: 0.0046
# Epoch 494/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 502us/step - loss: 0.0046
# Epoch 495/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 504us/step - loss: 0.0046
# Epoch 496/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 488us/step - loss: 0.0045
# Epoch 497/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 478us/step - loss: 0.0045
# Epoch 498/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0045
# Epoch 499/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 0.0045
# Epoch 500/500
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step - loss: 0.0045

# %%
# predict autoencoder
print('-' * 25 + 'Predict autoencoder model')
reconstruct = autoencoder.predict(df_pct_change_normalised)
# Out:
# -------------------------Predict autoencoder model
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 360us/step

# %%
# Inverse transform dataset with MinMax Scaler
print('-' * 25 + 'Inverse transform dataset with MinMax Scaler')
reconstruct_real = df_scaler.inverse_transform(reconstruct)
df_reconstruct_real = pd.DataFrame(data=reconstruct_real, columns=df_pct_change.columns)
# Out:
# -------------------------Inverse transform dataset with MinMax Scaler

# %%
print('-' * 25 + 'Calculate L2 norm as reconstruction loss metric')
df_recreation_error = getReconstructionErrorsDF(df_pct_change=df_pct_change,
                                                reconstructed_data=reconstruct_real)
# Out:
# -------------------------Calculate L2 norm as reconstruction loss metric

# %%
df_recreation_error
# Out:
#                ranking  stock_index  recreation_error
# stock_name
# NESTLEIND.NS         1           41          0.412935
# HDFCBANK.NS          2           25          0.463144
# HINDUNILVR.NS        3           36          0.488788
# TCS.NS               4           32          0.489211
# KOTAKBANK.NS         5           33          0.499979
# HCLTECH.NS           6           12          0.520578
# WIPRO.NS             7           38          0.530612
# ASIANPAINT.NS        8           30          0.531486
# MARUTI.NS            9           34          0.534654
# TITAN.NS            10           20          0.536030
# NTPC.NS             11            9          0.539260
# BAJAJ-AUTO.NS       12            8          0.550100
# RELIANCE.NS         13           37          0.556485
# POWERGRID.NS        14           47          0.558993
# LT.NS               15           26          0.563431
# ICICIBANK.NS        16           22          0.564454
# GRASIM.NS           17            6          0.564857
# ITC.NS              18           16          0.567038
# SBILIFE.NS          19           24          0.574082
# HDFCLIFE.NS         20            5          0.579475
# SUNPHARMA.NS        21           46          0.581902
# HEROMOTOCO.NS       22            3          0.582202
# AXISBANK.NS         23            1          0.583470
# M&M.NS              24           11          0.589548
# INFY.NS             25           44          0.591382
# CIPLA.NS            26           28          0.595950
# ULTRACEMCO.NS       27           39          0.599777
# TATACONSUM.NS       28            4          0.607397
# TECHM.NS            29           35          0.613003
# DRREDDY.NS          30           15          0.615390
# JSWSTEEL.NS         31            7          0.629065
# COALINDIA.NS        32           19          0.631702
# TATASTEEL.NS        33            2          0.649297
# SBIN.NS             34           10          0.649758
# BRITANNIA.NS        35            0          0.654578
# BHARTIARTL.NS       36           40          0.663131
# BAJAJFINSV.NS       37           49          0.700522
# BAJFINANCE.NS       38           43          0.701085
# EICHERMOT.NS        39           21          0.708051
# HINDALCO.NS         40           27          0.710639
# DIVISLAB.NS         41           29          0.715466
# APOLLOHOSP.NS       42           42          0.743155
# ADANIPORTS.NS       43           18          0.753017
# LTIM.NS             44           17          0.838174
# INDUSINDBK.NS       45           48          0.856780
# BPCL.NS             46           23          0.872382
# TATAMOTORS.NS       47           31          0.897515
# SHRIRAMFIN.NS       48           13          0.924115
# ONGC.NS             49           45          1.062179
# ADANIENT.NS         50           14          1.275675

# %%
filtered_stocks = df_recreation_error.head(stock_selection_number).index

# %%
filtered_stocks
# Out:
# Index(['NESTLEIND.NS', 'HDFCBANK.NS', 'HINDUNILVR.NS', 'TCS.NS',
#        'KOTAKBANK.NS', 'HCLTECH.NS', 'WIPRO.NS', 'ASIANPAINT.NS', 'MARUTI.NS',
#        'TITAN.NS', 'NTPC.NS', 'BAJAJ-AUTO.NS', 'RELIANCE.NS', 'POWERGRID.NS',
#        'LT.NS', 'ICICIBANK.NS', 'GRASIM.NS', 'ITC.NS', 'SBILIFE.NS',
#        'HDFCLIFE.NS'],
#       dtype='object', name='stock_name')

# %%
# store the list of selected stocks
# %store filtered_stocks
# Out:
# Stored 'filtered_stocks' (Index)

# %%
pip install pickleshare
# Out:
# Requirement already satisfied: pickleshare in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (0.7.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %store
# Out:
# Stored variables and their in-db values:
# df_close_full_stocks             ->             date  BRITANNIA.NS  AXISBANK.NS  TATAS
# filtered_stocks                  -> Index(['NESTLEIND.NS', 'HDFCBANK.NS', 'HINDUNILVR.
